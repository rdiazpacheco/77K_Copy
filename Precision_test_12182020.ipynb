# %%
## In this experiment we determine the effect of mounting and unmounting mulitmple times the same sample.

# %%
# Sample X-3
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201209
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  5 6 7 9 10 11 14 15 16
# Name of Data Folder PrTest
# Date of Data Batch 20201209
# [[Variables]]
#     Ic:  56.3397413 +/- 0.06726586 (0.12%) (init = 125)
#     n:   29.1146003 +/- 1.21740867 (4.18%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.810
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201209
# [[Variables]]
#     Ic:  56.5689857 +/- 0.07730478 (0.14%) (init = 125)
#     n:   28.2924489 +/- 1.21644397 (4.30%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.837
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201209
# [[Variables]]
#     Ic:  56.3753625 +/- 0.07347710 (0.13%) (init = 125)
#     n:   29.3421372 +/- 1.26176695 (4.30%) (init = 20)
# ...

# %%
# Sample X-4
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201209
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  20 21 22 23 25 26 27 68 69 70
# Name of Data Folder PrTest
# Date of Data Batch 20201209
# [[Variables]]
#     Ic:  64.7861389 +/- 0.02221278 (0.03%) (init = 125)
#     n:   39.8520627 +/- 0.88250596 (2.21%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.602
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201209
# [[Variables]]
#     Ic:  64.9721621 +/- 0.00926326 (0.01%) (init = 125)
#     n:   100.000000 +/- 0.00302968 (0.00%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.501
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201209
# [[Variables]]
#     Ic:  125.000000 +/- 3.0548e+10 (24438142604.74%) (init = 125)
#     n:   20.0000000 +/- 4.3962e+09 (21980843456.03%) (init = 20)
# ...

# %%
# Sample SOX 717-C
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201209
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  59 60 61 62 63 64
# Name of Data Folder PrTest
# Date of Data Batch 20201209
# [[Variables]]
#     Ic:  159.699132 +/- 0.10495529 (0.07%) (init = 125)
#     n:   46.2015762 +/- 1.46289947 (3.17%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.857
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201209
# [[Variables]]
#     Ic:  159.615409 +/- 0.08121871 (0.05%) (init = 125)
#     n:   37.4897638 +/- 0.89968054 (2.40%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.786
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201209
# [[Variables]]
#     Ic:  158.960571 +/- 0.13393829 (0.08%) (init = 125)
#     n:   42.1683929 +/- 1.48955588 (3.53%) (init = 20)
# ...

# %% [markdown]
# # Sample SOX 447-C 1
# %run calculate_IC.py

# %%
#Sample SOX 447-C 1
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201210
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  3 4 5 19 20 21
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  154.485212 +/- 0.10013191 (0.06%) (init = 125)
#     n:   47.2692377 +/- 1.41763025 (3.00%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.876
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  155.404793 +/- 0.13572123 (0.09%) (init = 125)
#     n:   34.3929073 +/- 0.96912899 (2.82%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.887
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  155.593251 +/- 0.11433210 (0.07%) (init = 125)
#     n:   38.8798333 +/- 1.11864773 (2.88%) (init = 20)
# ...

# %%
# Sample SOX 447-C 3
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201210
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  11 12 13 14 24 25 26 27 31 32 33
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  155.651645 +/- 0.04334193 (0.03%) (init = 125)
#     n:   51.6128699 +/- 1.19058879 (2.31%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.614
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  155.334161 +/- 0.02603637 (0.02%) (init = 125)
#     n:   91.6426921 +/- 2.42082631 (2.64%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.520
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  155.156477 +/- 0.04505990 (0.03%) (init = 125)
#     n:   51.5954097 +/- 1.18555130 (2.30%) (init = 20)
# ...

# %%
# Sample SOX 803-N2 1
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201210
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  52 53 54 60 61 62 71 72 73
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  179.994116 +/- 0.12967563 (0.07%) (init = 125)
#     n:   31.3776838 +/- 0.77597371 (2.47%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.786
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  180.747064 +/- 0.16939717 (0.09%) (init = 125)
#     n:   24.6363120 +/- 0.60965588 (2.47%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.839
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  178.004209 +/- 0.09321627 (0.05%) (init = 125)
#     n:   38.1496113 +/- 0.87052686 (2.28%) (init = 20)
# ...

# %%
# Sample SOX 803-N2 2
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201210
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  65 66 67 78
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  167.691004 +/- 0.05342706 (0.03%) (init = 125)
#     n:   31.6017968 +/- 0.50741090 (1.61%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.608
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  167.570172 +/- 0.04907518 (0.03%) (init = 125)
#     n:   34.1812062 +/- 0.54581319 (1.60%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.620
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  168.039393 +/- 0.04528603 (0.03%) (init = 125)
#     n:   30.3005241 +/- 0.44230477 (1.46%) (init = 20)
# ...

# %%
# Sample SOX 803-N2 3
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201210
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  42 43 45 55 56 57
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  180.542773 +/- 0.06493447 (0.04%) (init = 125)
#     n:   38.4717383 +/- 0.75965015 (1.97%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.715
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  180.136944 +/- 0.05103165 (0.03%) (init = 125)
#     n:   38.0439729 +/- 0.64238841 (1.69%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.632
# ##################plotting!!!############
# Name of Data Folder PrTest
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  180.017218 +/- 0.05152817 (0.03%) (init = 125)
#     n:   38.3152234 +/- 0.67119888 (1.75%) (init = 20)
# ...
