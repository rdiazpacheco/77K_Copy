# %%
## Precision Test 
##Test 1: PT06 OCT01_06 20210420 18-22
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  L
# start shot
#  18
# stop shot
#  22
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  178.734143 +/- 0.04523340 (0.03%) (init = 125)
#     n:   36.2294859 +/- 0.54939028 (1.52%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.579
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  178.728681 +/- 0.04916964 (0.03%) (init = 125)
#     n:   34.1883715 +/- 0.48205200 (1.41%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.672
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  178.360172 +/- 0.06406041 (0.04%) (init = 125)
#     n:   39.9702610 +/- 0.73085939 (1.83%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.777
# ...

# %%
## Precision Test 
##Test 3: PT06 OCT01_07 20210420 58-62
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  l
# start shot
#  58
# stop shot
#  62
# Name of Data Folder pt
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  174.373365 +/- 0.05070749 (0.03%) (init = 125)
#     n:   40.1817581 +/- 0.74292693 (1.85%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.623
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  174.715048 +/- 0.03950372 (0.02%) (init = 125)
#     n:   43.0938258 +/- 0.78946368 (1.83%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.355
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  174.433759 +/- 0.03953851 (0.02%) (init = 125)
#     n:   38.9095695 +/- 0.65853001 (1.69%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.304
# ...

# %%
## Precision Test 
##Test 3: PT06 OCT01_07 20210420 114-118
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  L
# start shot
#  114
# stop shot
#  118
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  174.231910 +/- 0.09581299 (0.05%) (init = 125)
#     n:   40.6858057 +/- 1.04357090 (2.56%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.827
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  174.704140 +/- 0.06120943 (0.04%) (init = 125)
#     n:   40.2122789 +/- 0.82028489 (2.04%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.702
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  174.643698 +/- 0.10686449 (0.06%) (init = 125)
#     n:   37.4647418 +/- 1.05997190 (2.83%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.794
# ...

# %%
## Precision Test 
##Test 1: PT07 OCT01_07 20210420 30-34
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  L
# start shot
#  30
# stop shot
#  34
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  162.371197 +/- 0.04124482 (0.03%) (init = 125)
#     n:   29.1080938 +/- 0.38936660 (1.34%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.467
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  162.566110 +/- 0.04018239 (0.02%) (init = 125)
#     n:   35.3140616 +/- 0.58845457 (1.67%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.357
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  162.266898 +/- 0.04224771 (0.03%) (init = 125)
#     n:   36.7929036 +/- 0.65989138 (1.79%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.395
# ...

# %%
## Precision Test 
##Test 1: PT07 OCT01_08 20210420 70-74
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  L
# start shot
#  70
# stop shot
#  74
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  168.253480 +/- 0.05727058 (0.03%) (init = 125)
#     n:   56.9913965 +/- 1.43780213 (2.52%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.763
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  168.582333 +/- 0.07993518 (0.05%) (init = 125)
#     n:   38.3380617 +/- 0.86764409 (2.26%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.788
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  168.153579 +/- 0.06903082 (0.04%) (init = 125)
#     n:   41.6720644 +/- 0.93490021 (2.24%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.760
# ...

# %%
## Precision Test 
##Test 1: PT07 OCT01_08 20210420 122-126
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  L
# start shot
#  122
# stop shot
#  126
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  168.929189 +/- 0.03341729 (0.02%) (init = 125)
#     n:   48.9710314 +/- 0.94606509 (1.93%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.188
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  169.047471 +/- 0.04125020 (0.02%) (init = 125)
#     n:   33.5669451 +/- 0.53724255 (1.60%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.284
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  169.350305 +/- 0.04031284 (0.02%) (init = 125)
#     n:   38.7372287 +/- 0.70260137 (1.81%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.245
# ...

# %%
## Precision Test 
##Test 1: PT01 OCT01_01 20210420 77-81
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  l
# start shot
#  77
# stop shot
#  81
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  174.314189 +/- 0.11471755 (0.07%) (init = 125)
#     n:   79.0624196 +/- 3.46517136 (4.38%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.912
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  174.534431 +/- 0.11928368 (0.07%) (init = 125)
#     n:   49.0817698 +/- 1.52371676 (3.10%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.888
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  174.695032 +/- 0.12796027 (0.07%) (init = 125)
#     n:   42.0809291 +/- 1.31931992 (3.14%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.864
# ...

# %%
## Precision Test 
##Test 2: PT01 OCT01_02 20210420 138-142
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  L
# start shot
#  138
# stop shot
#  142
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  173.479475 +/- 0.16362780 (0.09%) (init = 125)
#     n:   52.8131332 +/- 1.87271663 (3.55%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.936
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  175.093927 +/- 0.07039012 (0.04%) (init = 125)
#     n:   43.6186238 +/- 0.85029240 (1.95%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.838
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  175.362068 +/- 0.08575699 (0.05%) (init = 125)
#     n:   42.1694218 +/- 0.89125208 (2.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.863
# ...

# %%
## Precision Test 
##Test 1: PT02 OCT01_02 20210420 85-89
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  L
# start shot
#  85
# stop shot
#  89
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  151.944207 +/- 0.10321762 (0.07%) (init = 125)
#     n:   37.3534232 +/- 0.97424191 (2.61%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.859
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  152.120392 +/- 0.15687663 (0.10%) (init = 125)
#     n:   34.7206806 +/- 1.05280852 (3.03%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.908
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  151.117915 +/- 0.10772884 (0.07%) (init = 125)
#     n:   54.1704157 +/- 1.89239300 (3.49%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.892
# ...

# %%
## Precision Test 
##Test 2: PT02 OCT01_01 20210420 130-134
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  L
# start shot
#  130
# stop shot
#  134
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  141.787838 +/- 0.10928575 (0.08%) (init = 125)
#     n:   45.1831964 +/- 1.92601024 (4.26%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.796
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  143.338507 +/- 0.18559479 (0.13%) (init = 125)
#     n:   23.7925417 +/- 0.79699822 (3.35%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.847
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  141.668472 +/- 0.08417428 (0.06%) (init = 125)
#     n:   44.4262573 +/- 1.27219766 (2.86%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.845
# ...

# %%
## Precision Test 
##Test 1: PT05 OCT01_05 20210420 104-108
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  L
# start shot
#  104
# stop shot
#  108
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  70.9397816 +/- 0.10515177 (0.15%) (init = 125)
#     n:   30.8081631 +/- 1.69782418 (5.51%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.808
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  69.7823785 +/- 0.10238508 (0.15%) (init = 125)
#     n:   34.8581318 +/- 1.78606947 (5.12%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.872
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  70.6278305 +/- 0.17650406 (0.25%) (init = 125)
#     n:   29.7681967 +/- 1.85306326 (6.22%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.912
# ...

# %%
## Precision Test 
##Test 2: PT05 OCT01_08 20210420 160-164
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210420
# manual(m) or list(l)
#  L
# start shot
#  160
# stop shot
#  164
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  71.2256436 +/- 0.07311237 (0.10%) (init = 125)
#     n:   23.4686190 +/- 1.07805669 (4.59%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.361
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  70.4397988 +/- 0.04463873 (0.06%) (init = 125)
#     n:   33.7676672 +/- 1.36009949 (4.03%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.396
# ##################plotting!!!############
# Name of Data Folder PT
# Date of Data Batch 20210420
# [[Variables]]
#     Ic:  71.0728799 +/- 0.07817704 (0.11%) (init = 125)
#     n:   29.7773136 +/- 1.48501388 (4.99%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.660
# ...
