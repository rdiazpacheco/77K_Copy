# %%
#KIWI_Analysis_12102020
##Analysis of  degradation of 6 samples after some unspecified process.

# %%
import mpld3
mpld3.enable_notebook()

# %%
## Sample: 1, 248F-24
initial_IC =  <br>
post_IC =  <br>
degradation: <br>
KIWI Notes:

# %%
## Sample: 2, 248F-15
initial_IC =  <br>
post_IC =  <br>
degradation: <br>
KIWI Notes:

# %%
## Sample: 3, 248F-9
initial_IC =  <br>
post_IC =  <br>
degradation: <br>
KIWI Notes:

# %%
## Sample: 4, 248F-11
initial_IC =  <br>
post_IC =  <br>
degradation: <br>
KIWI Notes:

# %%
## Sample: 5, 248F-19
initial_IC =  <br>
post_IC =  <br>
degradation: <br>
KIWI Notes:

# %%
## Sample: 6, 248F-3
initial_IC =  <br>
post_IC =  <br>
degradation: <br>
KIWI Notes:

# %%
# Analysis begins here

# %%
initial_IC = 109.046061
post_IC = 51.7816144

degradation = 1 - post_IC/initial_IC
print(degradation)
# Out:
# 0.5251399828188199

# %%
# Sample 248F-24
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201211
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  13 14 15 16
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  178.335394 +/- 0.24241984 (0.14%) (init = 125)
#     n:   22.9526903 +/- 0.74121434 (3.23%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.862
# ##################plotting!!!############
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  177.267708 +/- 0.14256851 (0.08%) (init = 125)
#     n:   27.8659043 +/- 0.67263575 (2.41%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.848
# ##################plotting!!!############
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  176.007779 +/- 0.14185584 (0.08%) (init = 125)
#     n:   41.7887061 +/- 1.47622415 (3.53%) (init = 20)
# ...

# %%
# Sample 248F-9
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201211
# manual(m) or list(l)
#  l
# start shot
#  20
# stop shot
#  25
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  102.556048 +/- 0.05588330 (0.05%) (init = 125)
#     n:   27.5623435 +/- 0.67573759 (2.45%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.577
# ##################plotting!!!############
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  102.130792 +/- 0.08080891 (0.08%) (init = 125)
#     n:   29.8248652 +/- 0.86971050 (2.92%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.795
# ##################plotting!!!############
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  102.390660 +/- 0.05598861 (0.05%) (init = 125)
#     n:   29.3132180 +/- 0.73637441 (2.51%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# Sample 248F-11
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201211
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  29 44 45 46 47
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  169.482712 +/- 0.23660819 (0.14%) (init = 125)
#     n:   62.6993770 +/- 3.60738468 (5.75%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.948
# ##################plotting!!!############
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  175.210713 +/- 0.10877024 (0.06%) (init = 125)
#     n:   51.3513204 +/- 1.72946154 (3.37%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.855
# ##################plotting!!!############
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  175.739994 +/- 0.15439155 (0.09%) (init = 125)
#     n:   42.8481047 +/- 1.44249429 (3.37%) (init = 20)
# ...

# %%
# Sample 248F-19
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201211
# manual(m) or list(l)
#  l
# start shot
#  35
# stop shot
#  40
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  166.593295 +/- 0.17488917 (0.10%) (init = 125)
#     n:   67.7229262 +/- 3.23903207 (4.78%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.937
# ##################plotting!!!############
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  168.998090 +/- 0.12778774 (0.08%) (init = 125)
#     n:   39.5461594 +/- 1.10465248 (2.79%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.885
# ##################plotting!!!############
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  167.456418 +/- 0.17174307 (0.10%) (init = 125)
#     n:   57.2248529 +/- 2.46384919 (4.31%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# Sample 248F-15
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201211
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  51 55 56 57
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  139.318549 +/- 113029.593 (81130.33%) (init = 125)
#     n:   88.5170883 +/- 325258.528 (367452.81%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -1.000
# ##################plotting!!!############
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  217.683793 +/- 15.1437706 (6.96%) (init = 125)
#     n:   18.1550406 +/- 5.84410681 (32.19%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.992
# ##################plotting!!!############
# Name of Data Folder Kiwi
# Date of Data Batch 20201211
# [[Variables]]
#     Ic:  208.811730 +/- 7.85237266 (3.76%) (init = 125)
#     n:   26.6166872 +/- 7.74061746 (29.08%) (init = 20)
# ...

# %%
# Sample 248F-3
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201210
# manual(m) or list(l)
#  l
# start shot
#  81
# stop shot
#  82
# Name of Data Folder Kiwi
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  84.0744745 +/- 9.81302708 (11.67%) (init = 125)
#     n:   99.9999390 +/- 258.259467 (258.26%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.995
# ##################plotting!!!############
# Name of Data Folder Kiwi
# Date of Data Batch 20201210
# [[Variables]]
#     Ic:  163.559335 +/- 68578131.5 (41928595.22%) (init = 125)
#     n:   44.6253870 +/- 30882505.6 (69203894.22%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.934
# ##################plotting!!!############
