# %% [markdown]
# ##Pedro Pavao Experiment

# %%
## 1-PP 3-44
## Tests w Diff ramp rates
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210406
# manual(m) or list(l)
#  l
# start shot
#  3
# stop shot
#  40
# Name of Data Folder PP
# Date of Data Batch 20210406
# [[Variables]]
#     Ic:  178.389978 +/- 0.05264414 (0.03%) (init = 125)
#     n:   35.4118465 +/- 0.40692247 (1.15%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.840
# ##################plotting!!!############
# Name of Data Folder PP
# Date of Data Batch 20210406
# [[Variables]]
#     Ic:  177.869487 +/- 0.05588226 (0.03%) (init = 125)
#     n:   41.2088851 +/- 0.54753616 (1.33%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.861
# ##################plotting!!!############
# Name of Data Folder PP
# Date of Data Batch 20210406
# [[Variables]]
#     Ic:  177.773742 +/- 0.05269877 (0.03%) (init = 125)
#     n:   42.7981693 +/- 0.56873896 (1.33%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.855
# ...

# %%
## 2-PP 43-77
## Tests w Diff ramp rates
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210406
# manual(m) or list(l)
#  L
# start shot
#  43
# stop shot
#  77
# Name of Data Folder PP
# Date of Data Batch 20210406
# [[Variables]]
#     Ic:  158.198620 +/- 0.04468886 (0.03%) (init = 125)
#     n:   47.4169600 +/- 0.63418274 (1.34%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.868
# ##################plotting!!!############
# Name of Data Folder PP
# Date of Data Batch 20210406
# [[Variables]]
#     Ic:  157.858002 +/- 0.06181026 (0.04%) (init = 125)
#     n:   52.3926293 +/- 0.89590919 (1.71%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.911
# ##################plotting!!!############
# Name of Data Folder PP
# Date of Data Batch 20210406
# [[Variables]]
#     Ic:  158.269743 +/- 0.07943027 (0.05%) (init = 125)
#     n:   48.4097671 +/- 0.89882043 (1.86%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.926
# ...

# %%
## 3-PP 78-114
## Tests w Diff ramp rates
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210406
# manual(m) or list(l)
#  L
# start shot
#  100
# stop shot
#  114
# Name of Data Folder PP
# Date of Data Batch 20210406
# [[Variables]]
#     Ic:  92.1183980 +/- 276087.994 (299709.94%) (init = 125)
#     n:   14.5816243 +/- 64460.1790 (442064.46%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.999
# ##################plotting!!!############
# Name of Data Folder PP
# Date of Data Batch 20210406
# [[Variables]]
#     Ic:  91.9936680 +/- 332134.246 (361040.33%) (init = 125)
#     n:   14.6302892 +/- 76636.5540 (523821.18%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.999
# ##################plotting!!!############
# Name of Data Folder PP
# Date of Data Batch 20210406
# [[Variables]]
#     Ic:  92.1281335 +/- 279180.958 (303035.51%) (init = 125)
#     n:   14.5414143 +/- 64564.1470 (444001.84%) (init = 20)
# ...

# %%
## 4-PP 122-156
## Tests w Diff ramp rates
# %run calculate_IC.py

# %%
## 5-PP 161-199
## Tests w Diff ramp rates
# %run calculate_IC.py
