# %%
## AW_BARE_003
## Pre test 20210609 23-25
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210609
# manual(m) or list(l)
#  l
# start shot
#  23
# stop shot
#  25
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  170.503678 +/- 0.03481769 (0.02%) (init = 125)
#     n:   42.4678117 +/- 0.25645185 (0.60%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.939
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  171.326864 +/- 0.03511732 (0.02%) (init = 125)
#     n:   46.2957430 +/- 0.31600845 (0.68%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.935
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  170.895425 +/- 0.03404138 (0.02%) (init = 125)
#     n:   44.4959573 +/- 0.28552510 (0.64%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_BARE_003
## post test 20210623 18-21
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20200623
# manual(m) or list(l)
#  l
# start shot
#  18
# stop shot
#  21
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  177.859571 +/- 0.01277220 (0.01%) (init = 125)
#     n:   47.5781902 +/- 0.24472813 (0.51%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.668
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  178.409468 +/- 0.02854399 (0.02%) (init = 125)
#     n:   47.0458368 +/- 0.49229448 (1.05%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.726
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  177.828736 +/- 0.01938226 (0.01%) (init = 125)
#     n:   43.3084717 +/- 0.29547731 (0.68%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_BARE_004
## Pre test 20210609 
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20200623
# manual(m) or list(l)
#  l
# start shot
#
# stop shot
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\CFS Dropbox\Ruben Rui Diaz-Pacheco\77K_Copy\calculate_IC.py in <module>
#     486
#     487 if __name__ == "__main__":
# --> 488         shot_list, current_thresh, baseline_min, baseline_max, plot_result = main(command_line=False) #these variables are only for FALSE
#     489
#     490
#
# ~\CFS Dropbox\Ruben Rui Diaz-Pacheco\77K_Copy\calculate_IC.py in main(command_line)
#      94                 #reel_id = str(input("Input reel_id:\n"))
#      95                 #shot_list = input("Input shot list (separated by spaces): \n")
# ---> 96                 shot_list=shotList()
#      97                 current_thresh = 10.
#      98                 baseline_min = 10
#
# ...

# %%
## AW_BARE_004
## Pre test 20210623 24-28
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20200623
# manual(m) or list(l)
#  l
# start shot
#  24
# stop shot
#  28
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  169.284909 +/- 0.01741471 (0.01%) (init = 125)
#     n:   36.7056356 +/- 0.18592603 (0.51%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.749
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  169.388996 +/- 0.01891577 (0.01%) (init = 125)
#     n:   39.2438423 +/- 0.23575834 (0.60%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.735
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  168.896660 +/- 0.01832572 (0.01%) (init = 125)
#     n:   33.6157570 +/- 0.17765899 (0.53%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_PbSn_001
## Pre test 20210609 30-32
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210609
# manual(m) or list(l)
#  l
# start shot
#  30
# stop shot
#  32
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  168.959472 +/- 0.05793608 (0.03%) (init = 125)
#     n:   45.3832013 +/- 0.44223063 (0.97%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.951
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  168.919987 +/- 0.03628657 (0.02%) (init = 125)
#     n:   46.0570581 +/- 0.31131538 (0.68%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.941
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  166.979018 +/- 0.03997652 (0.02%) (init = 125)
#     n:   36.8911639 +/- 0.22558997 (0.61%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_PbSn_001
## Post test 20210623 31-35
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20200623
# manual(m) or list(l)
#  l
# start shot
#  31
# stop shot
#  35
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  167.189091 +/- 0.01950061 (0.01%) (init = 125)
#     n:   32.1990357 +/- 0.15162639 (0.47%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.787
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  167.263631 +/- 0.01793996 (0.01%) (init = 125)
#     n:   33.0802531 +/- 0.14920826 (0.45%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.779
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  167.273002 +/- 0.01826541 (0.01%) (init = 125)
#     n:   31.7938745 +/- 0.14616702 (0.46%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_PbSn_002
## Pre test 20210609 35-37
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210609
# manual(m) or list(l)
#  l
# start shot
#  35
# stop shot
#  37
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  166.765965 +/- 0.07532412 (0.05%) (init = 125)
#     n:   41.3551977 +/- 0.44757561 (1.08%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.958
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  162.867393 +/- 0.09938293 (0.06%) (init = 125)
#     n:   26.7908765 +/- 0.27202015 (1.02%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.952
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  166.931626 +/- 0.05536247 (0.03%) (init = 125)
#     n:   39.5665086 +/- 0.32730956 (0.83%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_PbSn_002
## Post test 20210623 38-42
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20200623
# manual(m) or list(l)
#  l
# start shot
#  38
# stop shot
#  42
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  167.665598 +/- 0.02204804 (0.01%) (init = 125)
#     n:   30.8908694 +/- 0.16733114 (0.54%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.753
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  168.026410 +/- 0.01730888 (0.01%) (init = 125)
#     n:   36.0955590 +/- 0.17898845 (0.50%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.753
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  168.214460 +/- 0.01795428 (0.01%) (init = 125)
#     n:   37.7576530 +/- 0.20044930 (0.53%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_PbSn_003
## Pre test 20210609 41-43
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210609
# manual(m) or list(l)
#  l
# start shot
#  41
# stop shot
#  43
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  167.879790 +/- 0.03342745 (0.02%) (init = 125)
#     n:   40.0137079 +/- 0.22227495 (0.56%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.939
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  168.103955 +/- 0.03356123 (0.02%) (init = 125)
#     n:   40.0462550 +/- 0.22027750 (0.55%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.940
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210609
# [[Variables]]
#     Ic:  168.663633 +/- 0.03276859 (0.02%) (init = 125)
#     n:   43.3980225 +/- 0.26315453 (0.61%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_PbSn_003
## Post test 20210623 45-49
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20200623
# manual(m) or list(l)
#  l
# start shot
#  45
# stop shot
#  49
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  171.559783 +/- 0.02312372 (0.01%) (init = 125)
#     n:   32.8723855 +/- 0.17421843 (0.53%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.808
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  172.436676 +/- 0.02784758 (0.02%) (init = 125)
#     n:   39.2370362 +/- 0.30144849 (0.77%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.801
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210623
# [[Variables]]
#     Ic:  172.165248 +/- 0.01909599 (0.01%) (init = 125)
#     n:   36.9972258 +/- 0.18315678 (0.50%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_PbSn_004
## Pre test 20210609 4-8
# %run calculate_IC.py

# %%
## AW_PbSn_004
## Pre test 20210623 51-55
# %run calculate_IC.py
