# %%
## Nickel CSMC degradation analysis

# %%
## Ni-DCC_001
## pre test 20210413 Shots 2-6
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210413
# manual(m) or list(l)
#  l
# start shot
#  2
# stop shot
#  6
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  144.499132 +/- 0.02990024 (0.02%) (init = 125)
#     n:   27.8701629 +/- 0.30509436 (1.09%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.361
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  144.698462 +/- 0.02132041 (0.01%) (init = 125)
#     n:   31.4011611 +/- 0.28584848 (0.91%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.252
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  144.986108 +/- 0.04985994 (0.03%) (init = 125)
#     n:   45.3460555 +/- 1.28989979 (2.84%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## Ni-DCC_001
## post test 20210503 Shots 3, 44
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210503
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  3 44
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  156.479914 +/- 52350031.0 (33454792.77%) (init = 125)
#     n:   70.4247658 +/- 65805433.9 (93440756.45%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.993
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  362.488802 +/- 77.7617878 (21.45%) (init = 125)
#     n:   3.10178082 +/- 0.55057482 (17.75%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.993
# ##################plotting!!!############

# %%
## Ni-DCC_002
## pre test 20210413 Shots 8-13
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210413
# manual(m) or list(l)
#  l
# start shot
#  8
# stop shot
#  13
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  74.9137071 +/- 0.08103451 (0.11%) (init = 125)
#     n:   31.4156548 +/- 1.07682986 (3.43%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.866
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  75.3747670 +/- 0.07524053 (0.10%) (init = 125)
#     n:   28.7276034 +/- 0.91243108 (3.18%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.838
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  75.2077970 +/- 0.07740151 (0.10%) (init = 125)
#     n:   28.9073107 +/- 0.91784894 (3.18%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## Ni-DCC_002
## post test 20210 Shots 10-14
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210503
# manual(m) or list(l)
#  l
# start shot
#  10
# stop shot
#  14
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  63.2395788 +/- 0.22325495 (0.35%) (init = 125)
#     n:   23.7710892 +/- 1.68120310 (7.07%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.912
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  63.3577541 +/- 0.17588473 (0.28%) (init = 125)
#     n:   26.4759630 +/- 1.76952235 (6.68%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.895
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  63.0278220 +/- 0.26587224 (0.42%) (init = 125)
#     n:   27.5829808 +/- 2.29757702 (8.33%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## Ni-DCC_003
## pre test 20210413 16-20
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210413
# manual(m) or list(l)
#  l
# start shot
#  16
# stop shot
#  20
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  144.437720 +/- 0.08694459 (0.06%) (init = 125)
#     n:   33.2509248 +/- 0.64544049 (1.94%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.879
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  145.048232 +/- 0.10845304 (0.07%) (init = 125)
#     n:   48.8864393 +/- 1.73898663 (3.56%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.877
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  145.991335 +/- 0.10322734 (0.07%) (init = 125)
#     n:   34.6294528 +/- 0.95829021 (2.77%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## Ni-DCC_003
## post test 20210 Shots 19-23
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210503
# manual(m) or list(l)
#  l
# start shot
#  19
# stop shot
#  23
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  132.681157 +/- 0.14809247 (0.11%) (init = 125)
#     n:   46.0748185 +/- 2.05393364 (4.46%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.904
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  134.008890 +/- 0.16375211 (0.12%) (init = 125)
#     n:   31.2428577 +/- 1.06518738 (3.41%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.897
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  133.600024 +/- 0.16553220 (0.12%) (init = 125)
#     n:   31.2809771 +/- 1.12828207 (3.61%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## Ni-DCC_004
## pre test 20210413 Shots 22-26
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210413
# manual(m) or list(l)
#  l
# start shot
#  22
# stop shot
#  26
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  103.580056 +/- 0.09727331 (0.09%) (init = 125)
#     n:   25.1420868 +/- 0.75470755 (3.00%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.782
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  103.716631 +/- 0.12247043 (0.12%) (init = 125)
#     n:   27.6124135 +/- 0.93063387 (3.37%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.859
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  103.740483 +/- 0.10078130 (0.10%) (init = 125)
#     n:   26.7701571 +/- 0.80600025 (3.01%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## Ni-DCC_004
## post test 20210 Shots 28-312
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210503
# manual(m) or list(l)
#  l
# start shot
#  28
# stop shot
#  32
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  94.9048232 +/- 0.12586285 (0.13%) (init = 125)
#     n:   25.5585622 +/- 1.09029500 (4.27%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.789
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  94.9130268 +/- 0.12078470 (0.13%) (init = 125)
#     n:   26.5085026 +/- 1.11207105 (4.20%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.793
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  95.0253928 +/- 0.11093534 (0.12%) (init = 125)
#     n:   25.8178109 +/- 1.07795008 (4.18%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## Ni-DCC_005
## pre test 20210413 Shots 29-33
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210413
# manual(m) or list(l)
#  l
# start shot
#  29
# stop shot
#  33
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  142.336313 +/- 0.14325376 (0.10%) (init = 125)
#     n:   29.9123046 +/- 0.88453385 (2.96%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.876
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  142.065122 +/- 0.12138041 (0.09%) (init = 125)
#     n:   29.2309944 +/- 0.77719642 (2.66%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.854
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  140.799203 +/- 0.09261513 (0.07%) (init = 125)
#     n:   46.5996617 +/- 1.49285051 (3.20%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## Ni-DCC_005
## post test 20210503 Shots36-41
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210503
# manual(m) or list(l)
#  l
# start shot
#  36
# stop shot
#  41
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  124.371553 +/- 0.21608120 (0.17%) (init = 125)
#     n:   38.6987166 +/- 2.01939162 (5.22%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.924
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  126.113434 +/- 0.07756780 (0.06%) (init = 125)
#     n:   26.4958790 +/- 0.57872012 (2.18%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.756
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  126.709310 +/- 0.11562774 (0.09%) (init = 125)
#     n:   23.9531350 +/- 0.63419467 (2.65%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## Ni-DCC_006
## pre test 20210413 36-40
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210413
# manual(m) or list(l)
#  l
# start shot
#  36
# stop shot
#  40
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  146.134163 +/- 0.09381659 (0.06%) (init = 125)
#     n:   54.3181368 +/- 1.89525156 (3.49%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.870
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  147.405256 +/- 0.12771121 (0.09%) (init = 125)
#     n:   36.9999625 +/- 1.14954031 (3.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.878
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210413
# [[Variables]]
#     Ic:  146.455754 +/- 0.10403290 (0.07%) (init = 125)
#     n:   49.5395204 +/- 1.70647482 (3.44%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## Ni-DCC_006
## pre test 20210503 Shots 3-7
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210503
# manual(m) or list(l)
#  l
# start shot
#  3
# stop shot
#  7
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  156.479914 +/- 52350031.0 (33454792.77%) (init = 125)
#     n:   70.4247658 +/- 65805433.9 (93440756.45%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.993
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  135.676428 +/- 0.09835761 (0.07%) (init = 125)
#     n:   31.2825993 +/- 0.82610677 (2.64%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.821
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210503
# [[Variables]]
#     Ic:  134.659039 +/- 0.07257375 (0.05%) (init = 125)
#     n:   41.6672718 +/- 1.13739913 (2.73%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...
