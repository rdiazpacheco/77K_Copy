# %%
#Tfmc Quiche Degrdatation Analysis

# %%
# DCC_PbSN_001
## pretest 20210119 Shots 3-6
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  3 4 6
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  177.422504 +/- 0.10146589 (0.06%) (init = 125)
#     n:   39.8387834 +/- 0.96198348 (2.41%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.852
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  177.122554 +/- 0.08838041 (0.05%) (init = 125)
#     n:   39.7160792 +/- 0.84877135 (2.14%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.845
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  177.150144 +/- 0.09048523 (0.05%) (init = 125)
#     n:   41.0129796 +/- 0.93892041 (2.29%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.839
# ##################plotting!!!############

# %%
# DCC_PbSN_001
## posttest 20210222 Shots 117-123
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210222
# manual(m) or list(l)
#  l
# start shot
#  117
# stop shot
#  123
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  120.729193 +/- 41.8366212 (34.65%) (init = 125)
#     n:   13.5101977 +/- 12.4328450 (92.03%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.996
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  142.711157 +/- 46.9893948 (32.93%) (init = 125)
#     n:   15.1180912 +/- 14.3198993 (94.72%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.996
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  147.344893 +/- 1921346.31 (1303978.90%) (init = 125)
#     n:   99.4309690 +/- 5894864.73 (5928600.30%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -1.000
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  1000.00000 +/- 17.8737325 (1.79%) (init = 125)
#     n:   2.48631733 +/- 1.13266761 (45.56%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.997
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  199.192391 +/- 27.6664979 (13.89%) (init = 125)
#     n:   20.4628502 +/- 12.0896258 (59.08%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.995
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  1000.00000 +/- 273.952389 (27.40%) (init = 125)
#     n:   2.06256411 +/- 0.28364001 (13.75%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.995
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  203.021585 +/- 817.237460 (402.54%) (init = 125)
#     n:   8.17101423 +/- 39.3327367 (481.37%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.998
# ##################plotting!!!############

# %%
# DCC_PbSN_003
## pretest 20210119 Shots 20-24
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  l
# start shot
#  20
# stop shot
#  24
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  158.683011 +/- 0.16040166 (0.10%) (init = 125)
#     n:   37.0797395 +/- 1.44214056 (3.89%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.858
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  158.530604 +/- 0.12350943 (0.08%) (init = 125)
#     n:   34.8622869 +/- 1.07692658 (3.09%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.827
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  160.400216 +/- 0.13867664 (0.09%) (init = 125)
#     n:   24.9108486 +/- 0.63534251 (2.55%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.813
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  159.058605 +/- 0.17244421 (0.11%) (init = 125)
#     n:   36.3889412 +/- 1.45560982 (4.00%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.866
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  159.237517 +/- 0.12309090 (0.08%) (init = 125)
#     n:   30.3379391 +/- 0.83986570 (2.77%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.813
# ##################plotting!!!############

# %%
# DCC_PbSN_003
## posttest 20210119 Shots 124-130
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210222
# manual(m) or list(l)
#  l
# start shot
#  124
# stop shot
#  130
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  794.692345 +/- 408.713040 (51.43%) (init = 125)
#     n:   2.20846225 +/- 0.55286564 (25.03%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.996
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  173.450754 +/- 6.01517468 (3.47%) (init = 125)
#     n:   15.5278643 +/- 2.35668744 (15.18%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.991
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  157.969277 +/- 2.00077334 (1.27%) (init = 125)
#     n:   34.7118292 +/- 4.66963145 (13.45%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.981
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~/77K_Copy/calculate_IC.py in <module>
#     491
#     492 #Execute I-V curve
# --> 493 plot_data(shot_list, baseline_min, baseline_max, current_thresh, plot_result)
#     494 #Ic,n = fit_data(shot_number,baseline_min,baseline_max, current_thresh, plot_result)
#     495
#
# ~/77K_Copy/calculate_IC.py in plot_data(shot_list, baseline_min, baseline_max, current_thresh, plot_result)
#     392         for shot_number in shot_list:
#     393                 # params_array = [Ic_temp, n_temp, Ic_error_temp, n_error_temp, currents_temp, voltages_temp, V_floor_temp, Vc_temp]
# --> 394                 params_array = fit_data(shot_number, baseline_min, baseline_max, current_thresh, plot_result)
#     395                 Ic_array[i] = params_array[0]/1
#     396                 n_array[i] = params_array[1]/1
#
# ~/77K_Copy/calculate_IC.py in fit_data(shot_number, baseline_min, baseline_max, current_thresh, plot_result)
#     166                 # Load the data from the data file using pandas
#     167
# --> 168                 data = pd.read_csv(data_file_path, header=header_lines)
#     169                 #data = pd.read_csv(data_file_path, header=10) #<<if using new pyplate data
#     170                 # Remove extraneous data columns
#
# /usr/lib64/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /usr/lib64/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# /usr/lib64/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /usr/lib64/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# /usr/lib64/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# ParserError: Passed header=11 but only 7 lines in file

# %%
# DCC_PbSN_005
## pretest 20210119 Shots 36-40
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  l
# start shot
#  36
# stop shot
#  40
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  177.779541 +/- 0.19489517 (0.11%) (init = 125)
#     n:   26.7766368 +/- 0.81407648 (3.04%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.860
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  176.815121 +/- 0.14667697 (0.08%) (init = 125)
#     n:   32.2534869 +/- 0.98393530 (3.05%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.825
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  177.303799 +/- 0.18756634 (0.11%) (init = 125)
#     n:   27.8225977 +/- 0.86482073 (3.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.855
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  175.851926 +/- 0.16367122 (0.09%) (init = 125)
#     n:   40.0961816 +/- 1.53812160 (3.84%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.863
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  176.345161 +/- 0.19909115 (0.11%) (init = 125)
#     n:   38.6553606 +/- 1.58888601 (4.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.887
# ##################plotting!!!############

# %%
# DCC_PbSN_005
## posttest 20210119 Shots 3-6
# %run calculate_IC.py

# %%
# DCC_PbSN_006
## pretest 20210119 Shots 46-50
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  l
# start shot
#  46
# stop shot
#  50
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  151.864986 +/- 0.18352927 (0.12%) (init = 125)
#     n:   23.7465221 +/- 0.71873756 (3.03%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.857
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  151.826073 +/- 0.16222957 (0.11%) (init = 125)
#     n:   23.0917825 +/- 0.65145460 (2.82%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.828
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  150.231786 +/- 0.20297672 (0.14%) (init = 125)
#     n:   33.0732358 +/- 1.43800052 (4.35%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.878
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  149.848957 +/- 0.17838068 (0.12%) (init = 125)
#     n:   34.3377945 +/- 1.38705624 (4.04%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.874
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  150.403637 +/- 0.15617241 (0.10%) (init = 125)
#     n:   35.0933573 +/- 1.36528081 (3.89%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.850
# ##################plotting!!!############

# %%
# DCC_PbSN_006
## posttest 20210222 Shots 132-136
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210222
# manual(m) or list(l)
#  l
# start shot
#  132
# stop shot
#  136
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  282.916668 +/- 50.3332668 (17.79%) (init = 125)
#     n:   4.97034141 +/- 1.03526507 (20.83%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.994
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  146.690782 +/- 0.55308690 (0.38%) (init = 125)
#     n:   30.1023066 +/- 1.53754904 (5.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.958
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  142.581654 +/- 0.21875890 (0.15%) (init = 125)
#     n:   38.0642105 +/- 1.35869734 (3.57%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.952
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  141.163168 +/- 0.27988057 (0.20%) (init = 125)
#     n:   46.5125660 +/- 2.32951185 (5.01%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.946
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  149.272092 +/- 0.60731638 (0.41%) (init = 125)
#     n:   16.6451526 +/- 0.67839133 (4.08%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.957
# ##################plotting!!!############

# %%
# DCC_PbSN_007
## pretest 20210119 Shots 56-60
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  l
# start shot
#  56
# stop shot
#  60
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  176.239168 +/- 0.13448941 (0.08%) (init = 125)
#     n:   38.8235873 +/- 1.26644321 (3.26%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.839
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  176.273906 +/- 0.15625491 (0.09%) (init = 125)
#     n:   39.9920361 +/- 1.46916371 (3.67%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.860
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  178.102091 +/- 0.13813855 (0.08%) (init = 125)
#     n:   27.5672080 +/- 0.71065015 (2.58%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.805
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  177.410806 +/- 0.16591292 (0.09%) (init = 125)
#     n:   37.6232802 +/- 1.41749644 (3.77%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.847
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  177.232786 +/- 0.15483729 (0.09%) (init = 125)
#     n:   39.6726794 +/- 1.49908533 (3.78%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.843
# ##################plotting!!!############

# %%
# DCC_PbSN_007
## posttest 20210119 Shots 3-6
# %run calculate_IC.py

# %%
# DCC_PbSN_008
## pretest 20210119 Shots 65-69
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  l
# start shot
#  65
# stop shot
#  69
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  181.177041 +/- 0.21440247 (0.12%) (init = 125)
#     n:   37.0239328 +/- 1.55273714 (4.19%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.881
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  180.393109 +/- 0.17589678 (0.10%) (init = 125)
#     n:   39.4727433 +/- 1.50346764 (3.81%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.873
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  181.081773 +/- 0.12394843 (0.07%) (init = 125)
#     n:   31.5481390 +/- 0.84616511 (2.68%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.796
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  179.996799 +/- 0.15823858 (0.09%) (init = 125)
#     n:   41.9556428 +/- 1.54414901 (3.68%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.871
# ##################plotting!!!############
# Name of Data Folder Qch
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  181.117949 +/- 0.16851234 (0.09%) (init = 125)
#     n:   39.8686584 +/- 1.50162864 (3.77%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.871
# ##################plotting!!!############

# %%
# DCC_PbSN_008
## posttest 20210119 Shots 3-6
# %run calculate_IC.py
