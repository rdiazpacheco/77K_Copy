# %%
# Degradtion analysis for TFMC TRANSTIONLEADS

# %% [markdown]
# ##### SOX 853-L_01
# ## pretest 20210301 Shots 69-73
# %run calculate_IC.py

# %% [markdown]
# # SOX 853-L_01
# ##pretest 20210301 Shots 69-73
# %run calculate_IC.py

# %%
## SOX 853-L_01
## post test 20210315 Shots 98-102
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210315
# manual(m) or list(l)
#  L
# start shot
#  98
# stop shot
#  102
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  145.718638 +/- 0.05321970 (0.04%) (init = 125)
#     n:   32.7201393 +/- 0.54081789 (1.65%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.735
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  145.740811 +/- 0.05711208 (0.04%) (init = 125)
#     n:   34.4229855 +/- 0.58946927 (1.71%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.782
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  146.223656 +/- 0.06174034 (0.04%) (init = 125)
#     n:   33.4443916 +/- 0.59380492 (1.78%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.786
# ...

# %%
## SOX 853-L_02
## pretest 20210301 Shots 77-81
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210301
# manual(m) or list(l)
#  L
# start shot
#  77
# stop shot
#  81
# Name of Data Folder TL
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  131.675136 +/- 0.23694430 (0.18%) (init = 125)
#     n:   75.0500743 +/- 5.15540388 (6.87%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.967
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  131.145509 +/- 0.09831059 (0.07%) (init = 125)
#     n:   92.2880767 +/- 4.21963084 (4.57%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.944
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  134.202003 +/- 0.17677661 (0.13%) (init = 125)
#     n:   42.4121852 +/- 1.53267231 (3.61%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.946
# ...

# %%
## SOX 853-L_02
## postest 20210315 Shots 90-94
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210315
# manual(m) or list(l)
#  L
# start shot
#  90
# stop shot
#  94
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  130.171742 +/- 0.05337530 (0.04%) (init = 125)
#     n:   29.2354539 +/- 0.48050482 (1.64%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.739
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  130.711405 +/- 0.04447681 (0.03%) (init = 125)
#     n:   26.0118214 +/- 0.35329513 (1.36%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.658
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  130.268582 +/- 0.05104256 (0.04%) (init = 125)
#     n:   30.8268946 +/- 0.53714460 (1.74%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.705
# ...

# %%
## SOX 865-R_01
## pretest 20210301 Shots 87-91
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210301
# manual(m) or list(l)
#  L
# start shot
#  87
# stop shot
#  91
# Name of Data Folder TL
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  157.165203 +/- 0.15737030 (0.10%) (init = 125)
#     n:   50.3949753 +/- 1.66272435 (3.30%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.946
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  158.268219 +/- 0.13936059 (0.09%) (init = 125)
#     n:   47.1883141 +/- 1.38204458 (2.93%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.937
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  156.089313 +/- 0.13445672 (0.09%) (init = 125)
#     n:   75.1430320 +/- 3.15312324 (4.20%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.946
# ...

# %%
## SOX 865-R_01
## post test 20210315 Shots 83-87
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210315
# manual(m) or list(l)
#  L
# start shot
#  83
# stop shot
#  87
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  159.178185 +/- 0.04706529 (0.03%) (init = 125)
#     n:   37.1362390 +/- 0.57353844 (1.54%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.718
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  159.684259 +/- 0.04511476 (0.03%) (init = 125)
#     n:   30.6860094 +/- 0.40904155 (1.33%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.650
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  159.701208 +/- 0.03818772 (0.02%) (init = 125)
#     n:   34.3214179 +/- 0.44573433 (1.30%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.623
# ...

# %%
## SOX 865-R_02
## pretest 20210301 Shots 100-104
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210301
# manual(m) or list(l)
#  L
# start shot
#  100
# stop shot
#  104
# Name of Data Folder TL
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  153.204460 +/- 0.28409155 (0.19%) (init = 125)
#     n:   71.5790356 +/- 4.70560948 (6.57%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.969
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  155.864997 +/- 0.71081775 (0.46%) (init = 125)
#     n:   54.6424413 +/- 5.34450297 (9.78%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.981
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  154.026314 +/- 0.23481316 (0.15%) (init = 125)
#     n:   98.3984381 +/- 8.22947733 (8.36%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.959
# ...

# %%
## SOX 865-R_02
## post test 20210315 Shots 76-80
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210315
# manual(m) or list(l)
#  L
# start shot
#  76
# stop shot
#  80
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  154.545919 +/- 0.14321863 (0.09%) (init = 125)
#     n:   30.3762827 +/- 0.75520311 (2.49%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.900
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  153.663602 +/- 0.05022653 (0.03%) (init = 125)
#     n:   30.3943078 +/- 0.44474494 (1.46%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.685
# ##################plotting!!!############
# Name of Data Folder TL
# Date of Data Batch 20210315
# [[Variables]]
#     Ic:  153.441160 +/- 0.05947071 (0.04%) (init = 125)
#     n:   33.5033434 +/- 0.57116222 (1.70%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.760
# ...
