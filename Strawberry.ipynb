# %%
## TFMC Strawberry Analysis

# %%
# GrPt_003
## pretest 20210217 Shots 
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210217
# manual(m) or list(l)
#  l
# start shot
#  9
# stop shot
#  10
# Name of Data Folder Stw
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  149.291563 +/- 0.03990384 (0.03%) (init = 125)
#     n:   31.1111351 +/- 0.47308741 (1.52%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.432
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  149.117152 +/- 0.03707276 (0.02%) (init = 125)
#     n:   30.4862694 +/- 0.44860484 (1.47%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.280
# ##################plotting!!!############

# %%
# GrPt_003
## post test 20210225 Shots 88-92
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210225
# manual(m) or list(l)
#  l
# start shot
#  88
# stop shot
#  92
# Name of Data Folder Stw
# Date of Data Batch 20210225
# [[Variables]]
#     Ic:  167.631759 +/- 0.50732787 (0.30%) (init = 125)
#     n:   66.6543971 +/- 5.69448481 (8.54%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.978
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210225
# [[Variables]]
#     Ic:  183.077306 +/- 2.13113470 (1.16%) (init = 125)
#     n:   19.3660112 +/- 1.54861995 (8.00%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.985
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210225
# [[Variables]]
#     Ic:  166.550965 +/- 0.73328974 (0.44%) (init = 125)
#     n:   100.000000 +/- 0.00162821 (0.00%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# GrPt_004
## pretest 20210217 Shots 16-20
# %run calculate_IC.py

# %%
# GrPt_004
## post test 20210226 Shots 6-10
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210226
# manual(m) or list(l)
#  l
# start shot
#  6
# stop shot
#  10
# Name of Data Folder Stw
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  170.507944 +/- 0.71292257 (0.42%) (init = 125)
#     n:   29.4251174 +/- 1.56615605 (5.32%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.977
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  162.031588 +/- 0.13972018 (0.09%) (init = 125)
#     n:   99.9999972 +/- 5.06534152 (5.07%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.956
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  168.248384 +/- 0.60326968 (0.36%) (init = 125)
#     n:   34.5860566 +/- 1.95703780 (5.66%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.974
# ...

# %%
# GrPt_005
## pretest 20210217 Shots 21-24
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210217
# manual(m) or list(l)
#  l
# start shot
#  21
# stop shot
#  24
# Name of Data Folder Stw
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  592.822683 +/- 313.994274 (52.97%) (init = 125)
#     n:   2.05133468 +/- 0.56495838 (27.54%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.995
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  224.226635 +/- 56.3360102 (25.12%) (init = 125)
#     n:   3.04149337 +/- 0.67154195 (22.08%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.992
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  104.868615 +/- 9.03839321 (8.62%) (init = 125)
#     n:   9.13767140 +/- 2.06218518 (22.57%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# GrPt_005
## posttest 20210225 Shots  78-82
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210225
# manual(m) or list(l)
#  l
# start shot
#  78
# stop shot
#  82
# Name of Data Folder Stw
# Date of Data Batch 20210225
# [[Variables]]
#     Ic:  152.719236 +/- 0.24662803 (0.16%) (init = 125)
#     n:   57.9448666 +/- 2.92617940 (5.05%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.964
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210225
# [[Variables]]
#     Ic:  156.986725 +/- 0.58846202 (0.37%) (init = 125)
#     n:   31.3181431 +/- 1.66720594 (5.32%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.975
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210225
# [[Variables]]
#     Ic:  151.277740 +/- 0.12421863 (0.08%) (init = 125)
#     n:   77.9878429 +/- 3.20138875 (4.10%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# GrPt_008
## pretest 20210217 Shots 25-29
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210217
# manual(m) or list(l)
#  l
# start shot
#  25
# stop shot
#  29
# Name of Data Folder Stw
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  96.3621077 +/- 0.10198897 (0.11%) (init = 125)
#     n:   18.6555286 +/- 0.73224290 (3.93%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.241
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  96.3615396 +/- 0.07911575 (0.08%) (init = 125)
#     n:   22.5235136 +/- 0.80799509 (3.59%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.309
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  97.8988823 +/- 0.29675284 (0.30%) (init = 125)
#     n:   20.5348899 +/- 1.02312579 (4.98%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# GrPt_008
## post test 20210226 Shots 16-20
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210226
# manual(m) or list(l)
#  l
# start shot
#  16
# stop shot
#  20
# Name of Data Folder Stw
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  166.413088 +/- 0.59082373 (0.36%) (init = 125)
#     n:   36.1428984 +/- 2.06162635 (5.70%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.975
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  163.478371 +/- 0.27725955 (0.17%) (init = 125)
#     n:   56.8013956 +/- 2.84791663 (5.01%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.966
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  161.299585 +/- 0.14529031 (0.09%) (init = 125)
#     n:   73.4762241 +/- 3.06018712 (4.16%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# DCC PbSn 022
## pretest 20210202 Shots 35-38
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210202
# manual(m) or list(l)
#  l
# start shot
#  35
# stop shot
#  38
# Name of Data Folder Stw
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  176.893693 +/- 0.35687514 (0.20%) (init = 125)
#     n:   32.1440168 +/- 1.73670304 (5.40%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.911
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  176.089490 +/- 0.18328880 (0.10%) (init = 125)
#     n:   39.1509815 +/- 1.65230674 (4.22%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.858
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  176.252137 +/- 0.22041888 (0.13%) (init = 125)
#     n:   37.5822515 +/- 1.74595283 (4.65%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# Dcc PbSn 022
## post test 20210225 Shots 68-72
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210225
# manual(m) or list(l)
#  l
# start shot
#  68
# stop shot
#  72
# Name of Data Folder Stw
# Date of Data Batch 20210225
# [[Variables]]
#     Ic:  161.254977 +/- 0.17676222 (0.11%) (init = 125)
#     n:   86.9401612 +/- 4.70186991 (5.41%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.959
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210225
# [[Variables]]
#     Ic:  165.814468 +/- 0.64354862 (0.39%) (init = 125)
#     n:   38.9857004 +/- 2.55872243 (6.56%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.977
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210225
# [[Variables]]
#     Ic:  160.041037 +/- 0.17353299 (0.11%) (init = 125)
#     n:   83.3605331 +/- 4.26022551 (5.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# Dcc PbSn 025
## pretest 20210202 shots 3-7
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210202
# manual(m) or list(l)
#  l
# start shot
#  3
# stop shot
#  7
# Name of Data Folder Stw
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  178.499434 +/- 0.20018522 (0.11%) (init = 125)
#     n:   28.0223267 +/- 0.95145451 (3.40%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.848
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  177.741946 +/- 0.17874441 (0.10%) (init = 125)
#     n:   37.6006987 +/- 1.54575078 (4.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.842
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  176.997693 +/- 0.21233055 (0.12%) (init = 125)
#     n:   38.9698916 +/- 1.79372451 (4.60%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.874
# ...

# %%
# Dcc PbSn 025
## pretest 20210226 Shots 25-30Stw

# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210226
# manual(m) or list(l)
#  l
# start shot
#  25
# stop shot
#  30
# Name of Data Folder Stw
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  190.624606 +/- 0.72987443 (0.38%) (init = 125)
#     n:   32.5471381 +/- 1.75286926 (5.39%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.977
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  190.844571 +/- 0.41706580 (0.22%) (init = 125)
#     n:   31.4585502 +/- 1.11308896 (3.54%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.968
# ##################plotting!!!############
# Name of Data Folder Stw
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  191.579671 +/- 0.43047206 (0.22%) (init = 125)
#     n:   30.3570842 +/- 1.05813950 (3.49%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...
