# %%
##### GrPt_015
## pretest 20210304 Shots 29-33
# %run calculate_IC.py

# %%
## GrPt_015
## posttest 20210402 Shots 83-87
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210402
# manual(m) or list(l)
#  l
# start shot
#  83
# stop shot
#  87
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  147.875968 +/- 0.06252237 (0.04%) (init = 125)
#     n:   28.8242221 +/- 0.56753182 (1.97%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.611
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  147.303167 +/- 0.04201515 (0.03%) (init = 125)
#     n:   29.9623782 +/- 0.45141982 (1.51%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.498
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  147.903015 +/- 0.04720871 (0.03%) (init = 125)
#     n:   28.6679031 +/- 0.45962333 (1.60%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.504
# ...

# %%
## 751-N3_006
## pretest 20210311 Shots 72-76
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210311
# manual(m) or list(l)
#  l
# start shot
#  72
# stop shot
#  76
# Name of Data Folder Pt
# Date of Data Batch 20210311
# [[Variables]]
#     Ic:  427.973374 +/- 75.9678465 (17.75%) (init = 125)
#     n:   2.70294960 +/- 0.35806195 (13.25%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.993
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210311
# [[Variables]]
#     Ic:  133.576622 +/- 0.25410928 (0.19%) (init = 125)
#     n:   70.2445202 +/- 5.23221781 (7.45%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.960
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210311
# [[Variables]]
#     Ic:  133.881484 +/- 0.37539907 (0.28%) (init = 125)
#     n:   99.9999971 +/- 12.8885509 (12.89%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## 751-N3_006
## post test 20210304 Shots 67-71
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210402
# manual(m) or list(l)
#  l
# start shot
#  67
# stop shot
#  71
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  130.927081 +/- 0.22141402 (0.17%) (init = 125)
#     n:   99.9999969 +/- 2.79668026 (2.80%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.961
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  134.026402 +/- 0.05036601 (0.04%) (init = 125)
#     n:   48.7717555 +/- 1.07760920 (2.21%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.802
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  133.866804 +/- 0.07081507 (0.05%) (init = 125)
#     n:   52.6763700 +/- 1.53780818 (2.92%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.855
# ...

# %%
### 751-N3_008
## pretest 20210311 Shots 57-61
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210311
# manual(m) or list(l)
#  l
# start shot
#  57
# stop shot
#  61
# Name of Data Folder Pt
# Date of Data Batch 20210311
# [[Variables]]
#     Ic:  134.497387 +/- 0.31527867 (0.23%) (init = 125)
#     n:   42.5025900 +/- 2.45265302 (5.77%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.958
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210311
# [[Variables]]
#     Ic:  134.395747 +/- 0.35868030 (0.27%) (init = 125)
#     n:   42.6403738 +/- 2.76062097 (6.47%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.959
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210311
# [[Variables]]
#     Ic:  449.596662 +/- 88.1056148 (19.60%) (init = 125)
#     n:   2.60679606 +/- 0.36390937 (13.96%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.993
# ...

# %%
## 751-N3_008
## pretest 20210304 Shots 89-93
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210402
# manual(m) or list(l)
#  l
# start shot
#  89
# stop shot
#  93
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  134.884247 +/- 0.06257634 (0.05%) (init = 125)
#     n:   38.5630451 +/- 0.96237650 (2.50%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.727
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  134.540547 +/- 0.05679541 (0.04%) (init = 125)
#     n:   33.8533377 +/- 0.73686637 (2.18%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.660
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  135.236291 +/- 0.09946321 (0.07%) (init = 125)
#     n:   36.3640077 +/- 1.13058877 (3.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.819
# ...

# %%
## 751-N3_002
## pretest 20210310 Shots 7-11
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210310
# manual(m) or list(l)
#  l
# start shot
#  7
# stop shot
#  11
# Name of Data Folder Pt
# Date of Data Batch 20210310
# [[Variables]]
#     Ic:  133.903909 +/- 0.07609007 (0.06%) (init = 125)
#     n:   49.2819084 +/- 1.07457682 (2.18%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.923
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210310
# [[Variables]]
#     Ic:  134.166530 +/- 0.07940398 (0.06%) (init = 125)
#     n:   49.1778851 +/- 1.11481957 (2.27%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.924
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210310
# [[Variables]]
#     Ic:  134.215943 +/- 0.07431451 (0.06%) (init = 125)
#     n:   50.5422588 +/- 1.12506641 (2.23%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.919
# ...

# %%
## 751-N3_002
## pretest 20210304 Shots 74-78
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210402
# manual(m) or list(l)
#  l
# start shot
#  74
# stop shot
#  78
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  137.183912 +/- 0.05831534 (0.04%) (init = 125)
#     n:   52.1850360 +/- 1.29839291 (2.49%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.828
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  137.723874 +/- 0.08338334 (0.06%) (init = 125)
#     n:   39.2762093 +/- 0.95799380 (2.44%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.864
# ##################plotting!!!############
# Name of Data Folder Pt
# Date of Data Batch 20210402
# [[Variables]]
#     Ic:  137.539678 +/- 0.08882863 (0.06%) (init = 125)
#     n:   40.9602563 +/- 1.06303014 (2.60%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.875
# ...
