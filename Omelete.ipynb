# %%
##Omelete post test

# %%
# Sample PbSn_005
## PRE TEST 12/23/2020 30-34
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201223
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  33
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# Empty dataframe!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/77K_Copy/calculate_IC.py in <module>
#     491
#     492 #Execute I-V curve
# --> 493 plot_data(shot_list, baseline_min, baseline_max, current_thresh, plot_result)
#     494 #Ic,n = fit_data(shot_number,baseline_min,baseline_max, current_thresh, plot_result)
#     495
#
# ~/77K_Copy/calculate_IC.py in plot_data(shot_list, baseline_min, baseline_max, current_thresh, plot_result)
#     393                 # params_array = [Ic_temp, n_temp, Ic_error_temp, n_error_temp, currents_temp, voltages_temp, V_floor_temp, Vc_temp]
# ...

# %%
# Sample PbSn_005
## POST TEST 02/02/2021 48-52
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210201
# manual(m) or list(l)
#  l
# start shot
#  48
# stop shot
#  52
# Name of Data Folder Omelete
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  76.7465312 +/- 0.18480622 (0.24%) (init = 125)
#     n:   22.1536604 +/- 1.33617703 (6.03%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.835
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  76.3828997 +/- 0.21696884 (0.28%) (init = 125)
#     n:   24.8109593 +/- 1.69667089 (6.84%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.883
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  78.2427004 +/- 0.28785488 (0.37%) (init = 125)
#     n:   20.6178380 +/- 1.48732823 (7.21%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# Sample PbSn_003
## PRE TEST 12/23/2020 14-18
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201223
# manual(m) or list(l)
#  l
# start shot
#  14
# stop shot
#  18
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  158.632338 +/- 0.20746758 (0.13%) (init = 125)
#     n:   24.0764267 +/- 0.75697679 (3.14%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.871
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  159.002826 +/- 0.16562304 (0.10%) (init = 125)
#     n:   23.7518738 +/- 0.68074873 (2.87%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.823
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  158.869728 +/- 0.13564761 (0.09%) (init = 125)
#     n:   24.6207235 +/- 0.65554345 (2.66%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# Sample PbSn_003
## Post test 02/01/2021 69-73
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210201
# manual(m) or list(l)
#  l
# start shot
#  69
# stop shot
#  73
# Name of Data Folder Omelete
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  134.101624 +/- 0.19968253 (0.15%) (init = 125)
#     n:   27.6871236 +/- 1.13678785 (4.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.872
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  133.988806 +/- 0.14608588 (0.11%) (init = 125)
#     n:   28.7570274 +/- 1.04163480 (3.62%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.826
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  134.218303 +/- 0.18348694 (0.14%) (init = 125)
#     n:   27.9181117 +/- 1.13546339 (4.07%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# Sample PbSn_002
## PRE TEST 12/23/2020 4-8
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201223
# manual(m) or list(l)
#  l
# start shot
#  4
# stop shot
#  8
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  178.396832 +/- 0.17770836 (0.10%) (init = 125)
#     n:   39.4730452 +/- 1.52261503 (3.86%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.877
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  177.507139 +/- 0.14641232 (0.08%) (init = 125)
#     n:   44.8426354 +/- 1.79680529 (4.01%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.845
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  177.452319 +/- 0.16133470 (0.09%) (init = 125)
#     n:   48.3881738 +/- 2.03976869 (4.22%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# Sample PbSn_002
## post TEST 
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201223
# manual(m) or list(l)
#  l
# start shot
#  4
# stop shot
#  8
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  178.396832 +/- 0.17770836 (0.10%) (init = 125)
#     n:   39.4730452 +/- 1.52261503 (3.86%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.877
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  177.507139 +/- 0.14641232 (0.08%) (init = 125)
#     n:   44.8426354 +/- 1.79680529 (4.01%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.845
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  177.452319 +/- 0.16133470 (0.09%) (init = 125)
#     n:   48.3881738 +/- 2.03976869 (4.22%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# Sample PbSn_006
## PRE TEST 12/23/2020 36-40
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201223
# manual(m) or list(l)
#  l
# start shot
#  36
# stop shot
#  40
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  174.012351 +/- 0.19125765 (0.11%) (init = 125)
#     n:   40.1154927 +/- 1.74022588 (4.34%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.874
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  174.064359 +/- 0.12712930 (0.07%) (init = 125)
#     n:   31.6213387 +/- 0.94310707 (2.98%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.774
# ##################plotting!!!############
# Name of Data Folder Omelete
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  173.062495 +/- 0.18813020 (0.11%) (init = 125)
#     n:   41.5277481 +/- 1.83025321 (4.41%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# Sample PbSn_006
## PRE TEST 12/23/2020 4-8
# %run calculate_IC.py
