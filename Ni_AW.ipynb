# %%
## AW_SPI22_001
## pre test 20210617 12-16
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210617
# manual(m) or list(l)
#  L
# start shot
#  12
# stop shot
#  16
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  175.831414 +/- 0.03720400 (0.02%) (init = 125)
#     n:   31.5376756 +/- 0.16005819 (0.51%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.927
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  175.618052 +/- 0.03810367 (0.02%) (init = 125)
#     n:   30.9962311 +/- 0.15975220 (0.52%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.926
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  175.803774 +/- 0.03690528 (0.02%) (init = 125)
#     n:   30.5617924 +/- 0.15391502 (0.50%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI22_001
## post test 20210622 4-8
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210622
# manual(m) or list(l)
#  AW_Ni
# start shot
#  4
# stop shot
#  8
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  146.813049 +/- 0.03866550 (0.03%) (init = 125)
#     n:   33.0479535 +/- 0.51173406 (1.55%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.485
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  144.078397 +/- 0.04434809 (0.03%) (init = 125)
#     n:   18.7638292 +/- 0.18704513 (1.00%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.543
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  147.554477 +/- 0.02447595 (0.02%) (init = 125)
#     n:   38.1002153 +/- 0.42743611 (1.12%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI22_002
## pre test 20210617 23-27
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210617
# manual(m) or list(l)
#  L
# start shot
#  23
# stop shot
#  27
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  100.717429 +/- 0.45334984 (0.45%) (init = 125)
#     n:   2.56089668 +/- 0.02463809 (0.96%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.937
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  130.737163 +/- 0.33064963 (0.25%) (init = 125)
#     n:   3.11338495 +/- 0.02988491 (0.96%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.851
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  137.675938 +/- 0.34912884 (0.25%) (init = 125)
#     n:   3.76254795 +/- 0.04057418 (1.08%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI22_002
## post test 20210617 13-17
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210622
# manual(m) or list(l)
#  l
# start shot
#  13
# stop shot
#  17
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  177.412274 +/- 0.02197066 (0.01%) (init = 125)
#     n:   30.3691831 +/- 0.21640463 (0.71%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.369
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  177.845841 +/- 0.01847601 (0.01%) (init = 125)
#     n:   32.9636034 +/- 0.20894309 (0.63%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.418
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  176.950118 +/- 0.02103607 (0.01%) (init = 125)
#     n:   26.9918671 +/- 0.17041928 (0.63%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI22_003
## pre test 20210617 31-35
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210617
# manual(m) or list(l)
#  l
# start shot
#  31
# stop shot
#  35
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  176.647398 +/- 0.03234905 (0.02%) (init = 125)
#     n:   31.4758888 +/- 0.17176767 (0.55%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.885
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  176.710109 +/- 0.03126893 (0.02%) (init = 125)
#     n:   32.7407921 +/- 0.17594197 (0.54%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.889
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  176.304069 +/- 0.02774092 (0.02%) (init = 125)
#     n:   31.7590599 +/- 0.14873029 (0.47%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI22_003
## post test 20210622 37-41
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210622
# manual(m) or list(l)
#  l
# start shot
#  37
# stop shot
#  41
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  178.520159 +/- 0.04322589 (0.02%) (init = 125)
#     n:   43.5211076 +/- 0.92539988 (2.13%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.139
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  177.893804 +/- 0.01952962 (0.01%) (init = 125)
#     n:   34.8200782 +/- 0.25822386 (0.74%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.304
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  177.779701 +/- 0.01947493 (0.01%) (init = 125)
#     n:   32.5760372 +/- 0.23297722 (0.72%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI22_004
## pre test 20210617 38-42
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210617
# manual(m) or list(l)
#  l
# start shot
#  38
# stop shot
#  42
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  109.938862 +/- 0.35663027 (0.32%) (init = 125)
#     n:   2.59624391 +/- 0.02251723 (0.87%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.902
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  106.156795 +/- 0.38919155 (0.37%) (init = 125)
#     n:   2.52301203 +/- 0.02297199 (0.91%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.912
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  128.598426 +/- 0.31516136 (0.25%) (init = 125)
#     n:   3.14421416 +/- 0.02923171 (0.93%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI22_004
## post test 20210622 43-47
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210622
# manual(m) or list(l)
#  l
# start shot
#  43
# stop shot
#  47
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  180.969442 +/- 0.04081751 (0.02%) (init = 125)
#     n:   45.4713070 +/- 0.94058552 (2.07%) (init = 20)
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  178.919942 +/- 0.03244663 (0.02%) (init = 125)
#     n:   26.5930459 +/- 0.25857581 (0.97%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.163
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  178.914958 +/- 0.03241596 (0.02%) (init = 125)
#     n:   27.3306312 +/- 0.27710536 (1.01%) (init = 20)
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
# ...

# %%
## AW_SPI57_001
## pre test 20210617 2-6
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210617
# manual(m) or list(l)
#  l
# start shot
#  2
# stop shot
#  6
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  133.266552 +/- 0.03227553 (0.02%) (init = 125)
#     n:   27.3635012 +/- 0.12941172 (0.47%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.937
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  133.373892 +/- 0.03169617 (0.02%) (init = 125)
#     n:   28.0084200 +/- 0.13415352 (0.48%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.935
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  132.919732 +/- 0.03168992 (0.02%) (init = 125)
#     n:   26.3113692 +/- 0.11755705 (0.45%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI57_001
## post test 20210622 20-24
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210622
# manual(m) or list(l)
#  l
# start shot
#  20
# stop shot
#  24
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  152.502234 +/- 0.01789060 (0.01%) (init = 125)
#     n:   34.2360711 +/- 0.27667705 (0.81%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.144
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  152.206454 +/- 0.01590916 (0.01%) (init = 125)
#     n:   35.2554948 +/- 0.25382999 (0.72%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.277
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  152.074492 +/- 0.01712172 (0.01%) (init = 125)
#     n:   33.6953570 +/- 0.24524922 (0.73%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI57_002
## pre test 20210617 44-48
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210617
# manual(m) or list(l)
#  l
# start shot
#  44
# stop shot
#  48
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  158.730588 +/- 0.02746306 (0.02%) (init = 125)
#     n:   30.8416047 +/- 0.12463077 (0.40%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.927
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  158.112359 +/- 0.02784566 (0.02%) (init = 125)
#     n:   28.2070110 +/- 0.10530107 (0.37%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.928
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  158.842010 +/- 0.02414819 (0.02%) (init = 125)
#     n:   31.0792786 +/- 0.11119298 (0.36%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI57_002
## post test 20210622 26-30
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210622
# manual(m) or list(l)
#  l
# start shot
#  26
# stop shot
#  30
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  153.422115 +/- 0.02254869 (0.01%) (init = 125)
#     n:   28.3509968 +/- 0.23810892 (0.84%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.154
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  153.644615 +/- 0.02033913 (0.01%) (init = 125)
#     n:   28.9437207 +/- 0.21873074 (0.76%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.265
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  153.509219 +/- 0.02039290 (0.01%) (init = 125)
#     n:   28.9730791 +/- 0.22061096 (0.76%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI57_003
## pre test 20210617 68-72
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210617
# manual(m) or list(l)
#  l
# start shot
#  68
# stop shot
#  72
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  162.069489 +/- 0.01630807 (0.01%) (init = 125)
#     n:   37.0708365 +/- 0.25471217 (0.69%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.405
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  162.322823 +/- 0.01809111 (0.01%) (init = 125)
#     n:   35.8972860 +/- 0.28530434 (0.79%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.197
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  162.077470 +/- 0.01736652 (0.01%) (init = 125)
#     n:   37.3771241 +/- 0.28268074 (0.76%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI57_003
## post test 20210617 50-54
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210622
# manual(m) or list(l)
#  l
# start shot
#  50
# stop shot
#  54
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  160.168568 +/- 0.02300552 (0.01%) (init = 125)
#     n:   45.2771899 +/- 0.53250167 (1.18%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.441
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  159.152389 +/- 0.02016022 (0.01%) (init = 125)
#     n:   34.4550393 +/- 0.27527362 (0.80%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.429
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  159.603482 +/- 0.02276106 (0.01%) (init = 125)
#     n:   35.1334499 +/- 0.34427537 (0.98%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI57_004
## pre test 20210617 60-64
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210617
# manual(m) or list(l)
#  l
# start shot
#  60
# stop shot
#  64
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  163.188645 +/- 0.01803301 (0.01%) (init = 125)
#     n:   39.1294601 +/- 0.30026100 (0.77%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.469
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  162.715000 +/- 0.02061562 (0.01%) (init = 125)
#     n:   34.4615165 +/- 0.27851810 (0.81%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.403
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210617
# [[Variables]]
#     Ic:  162.798259 +/- 0.01713824 (0.01%) (init = 125)
#     n:   36.9153104 +/- 0.26609500 (0.72%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## AW_SPI57_004
## post test 20210617 57-61
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210622
# manual(m) or list(l)
#  l
# start shot
#  57
# stop shot
#  61
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  162.082005 +/- 0.02276763 (0.01%) (init = 125)
#     n:   42.8689902 +/- 0.50489293 (1.18%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.226
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  162.021766 +/- 0.01615171 (0.01%) (init = 125)
#     n:   41.5528114 +/- 0.28962970 (0.70%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.553
# ##################plotting!!!############
# Name of Data Folder AW_Ni
# Date of Data Batch 20210622
# [[Variables]]
#     Ic:  161.874818 +/- 0.01724505 (0.01%) (init = 125)
#     n:   38.9261529 +/- 0.24976269 (0.64%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...
