# %%
# Degradtion analysis for TFMC Toast

# %%
## GrPt001
## pretest 20210217 Shots 9-13
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210217
# manual(m) or list(l)
#  l
# start shot
#  9
# stop shot
#  13
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  149.291563 +/- 0.03990384 (0.03%) (init = 125)
#     n:   31.1111351 +/- 0.47308741 (1.52%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.432
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  149.117152 +/- 0.03707276 (0.02%) (init = 125)
#     n:   30.4862694 +/- 0.44860484 (1.47%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.280
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  149.165499 +/- 0.05040496 (0.03%) (init = 125)
#     n:   36.2941745 +/- 0.77681030 (2.14%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.511
# ...

# %%
## GrPt001
## post test 20210301 Shots 44-48
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210301
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  44 46 47
# Name of Data Folder Tst
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  150.303525 +/- 6418574.17 (4270408.28%) (init = 125)
#     n:   47.8538523 +/- 5193599.44 (10853043.56%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.999
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  152.481404 +/- 9.15417179 (6.00%) (init = 125)
#     n:   99.9999981 +/- 2.74793529 (2.75%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.996
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  193.940862 (init = 125)
#     n:   97.2682619 (init = 20)
# ##################plotting!!!############
# ...

# %%
## GrPt002
## pretest 20210217 Shots 16-20
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210217
# manual(m) or list(l)
#  l
# start shot
#  16
# stop shot
#  20
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  188.443486 +/- 0.12890224 (0.07%) (init = 125)
#     n:   74.7666229 +/- 3.10486057 (4.15%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.914
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  188.974734 +/- 0.18453250 (0.10%) (init = 125)
#     n:   64.0423416 +/- 3.02532564 (4.72%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.926
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  190.199810 +/- 0.24845553 (0.13%) (init = 125)
#     n:   46.0250242 +/- 1.96995085 (4.28%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## GrPt002
## post test 20210301 Shots 35-42
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210301
# manual(m) or list(l)
#  l
# start shot
#  35
# stop shot
#  42
# Name of Data Folder Tst
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  150.171449 +/- 12.1676560 (8.10%) (init = 125)
#     n:   99.9999928 +/- 160.118827 (160.12%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.995
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  178.201877 +/- 15.9045012 (8.92%) (init = 125)
#     n:   99.9999786 +/- 19.6475485 (19.65%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.996
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  199.667055 +/- 4.60707726 (2.31%) (init = 125)
#     n:   34.5599689 +/- 7.48024997 (21.64%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## GrPt007
## pretest 20210222 Shots 24-28
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210222
# manual(m) or list(l)
#  l
# start shot
#  24
# stop shot
#  28
# Name of Data Folder Tst
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  171.498227 +/- 0.66389364 (0.39%) (init = 125)
#     n:   49.7067879 +/- 3.95922736 (7.97%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.979
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  172.364662 +/- 0.87547904 (0.51%) (init = 125)
#     n:   63.7084315 +/- 8.54695664 (13.42%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.978
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  169.357812 +/- 0.37027036 (0.22%) (init = 125)
#     n:   99.9999920 +/- 10.8242712 (10.82%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## GrPt007
## post test 20210226 Shots 34-35
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210226
# manual(m) or list(l)
#  l
# start shot
#  34
# stop shot
#  36
# Name of Data Folder Tst
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  190.698154 +/- 4.48525198 (2.35%) (init = 125)
#     n:   27.9832551 +/- 5.15976188 (18.44%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.991
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  190.450295 +/- 0.31672210 (0.17%) (init = 125)
#     n:   28.4841851 +/- 0.77736125 (2.73%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.962
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  131.094350 +/- 0.27122419 (0.21%) (init = 125)
#     n:   25.9308302 +/- 0.81176595 (3.13%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## GrPt009
## pretest 20210222 Shots 36-40
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210222
# manual(m) or list(l)
#  l
# start shot
#  36
# stop shot
#  40
# Name of Data Folder Tst
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  166.939935 +/- 0.20561187 (0.12%) (init = 125)
#     n:   97.5850009 +/- 6.26333919 (6.42%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.963
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  170.270101 +/- 0.83346937 (0.49%) (init = 125)
#     n:   61.3934893 +/- 7.13692455 (11.62%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.981
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  181.957261 +/- 0.76325459 (0.42%) (init = 125)
#     n:   17.2567557 +/- 0.60253119 (3.49%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %% [markdown]
# # GrPt009
# ## post test 20210301 Shots 49-51
# %run calculate_IC.py

# %%
##GrPt009
#post test 20210301 Shots 49-51¶
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210301
# manual(m) or list(l)
#  l
# start shot
#  50
# stop shot
#  51
# Name of Data Folder Tst
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  179.579447 +/- 68.7651589 (38.29%) (init = 125)
#     n:   20.9186733 +/- 29.2631884 (139.89%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.996
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  173.149854 +/- 0.79601472 (0.46%) (init = 125)
#     n:   25.6994280 +/- 1.30499410 (5.08%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.979
# ##################plotting!!!############

# %%
## GrPt012
## pretest 20210217 Shots 40-44
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210217
# manual(m) or list(l)
#  l
# start shot
#  40
# stop shot
#  44
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  166.241142 +/- 0.04886082 (0.03%) (init = 125)
#     n:   32.2496501 +/- 0.51978940 (1.61%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.549
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  166.657440 +/- 0.04365112 (0.03%) (init = 125)
#     n:   33.6257173 +/- 0.55243983 (1.64%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.393
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  166.969634 +/- 0.04894644 (0.03%) (init = 125)
#     n:   43.5708775 +/- 1.00451975 (2.31%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## GrPt012
## post test 20210301 Shots 55-60
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210301
# manual(m) or list(l)
#  l
# start shot
#  55
# stop shot
#  60
# Name of Data Folder Tst
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  169.750991 +/- 1.29572040 (0.76%) (init = 125)
#     n:   25.7096289 +/- 1.91110511 (7.43%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.982
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  160.947385 +/- 0.22176678 (0.14%) (init = 125)
#     n:   60.8850621 +/- 2.84277897 (4.67%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.961
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210301
# [[Variables]]
#     Ic:  162.899374 +/- 0.20031124 (0.12%) (init = 125)
#     n:   41.4390212 +/- 1.34435996 (3.24%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## GrPt018
## pretest 20210217 Shots 50-54
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210217
# manual(m) or list(l)
#  l
# start shot
#  50
# stop shot
#  54
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  170.813532 +/- 0.05135623 (0.03%) (init = 125)
#     n:   31.8556228 +/- 0.54536218 (1.71%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.466
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  170.133112 +/- 0.05242824 (0.03%) (init = 125)
#     n:   27.8436325 +/- 0.39176800 (1.41%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.593
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210217
# [[Variables]]
#     Ic:  170.614444 +/- 0.04500415 (0.03%) (init = 125)
#     n:   33.8901393 +/- 0.52262921 (1.54%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## GrPt018
## pretest 20210226 Shots 48-55
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210226
# manual(m) or list(l)
#  l
# start shot
#  48
# stop shot
#  55
# Name of Data Folder Tst
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  178.941812 +/- 74.9173557 (41.87%) (init = 125)
#     n:   38.3435483 +/- 101.614553 (265.01%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.997
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  194.440481 +/- 3.75006001 (1.93%) (init = 125)
#     n:   29.0736162 +/- 4.69403439 (16.15%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.990
# ##################plotting!!!############
# Name of Data Folder Tst
# Date of Data Batch 20210226
# [[Variables]]
#     Ic:  196.472944 +/- 0.43711373 (0.22%) (init = 125)
#     n:   26.3155393 +/- 0.80901946 (3.07%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...
