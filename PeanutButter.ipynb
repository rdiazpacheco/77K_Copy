# %%
##TFMC degradation analysis for Peanut Butter

# %%
# DCC_PbSN_02
## pretest 20210119 Shots 10-14
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  L
# start shot
#  10
# stop shot
#  14
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  174.770474 +/- 0.14897098 (0.09%) (init = 125)
#     n:   39.8151072 +/- 1.36867304 (3.44%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.865
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  175.500772 +/- 0.18648103 (0.11%) (init = 125)
#     n:   37.5052155 +/- 1.46415914 (3.90%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.875
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  175.846618 +/- 0.16424377 (0.09%) (init = 125)
#     n:   38.4308735 +/- 1.43864870 (3.74%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.858
# ...

# %%
# DCC_PbSN_02
## postest 20210201 Shots 10-15
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210201
# manual(m) or list(l)
#  L
# start shot
#  10
# stop shot
#  15
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  171.920770 +/- 0.19814132 (0.12%) (init = 125)
#     n:   35.8413983 +/- 1.41334018 (3.94%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.883
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  171.907692 +/- 0.19530917 (0.11%) (init = 125)
#     n:   36.6265168 +/- 1.50300530 (4.10%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.877
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  172.067425 +/- 0.21333572 (0.12%) (init = 125)
#     n:   36.2215453 +/- 1.50646510 (4.16%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.890
# ...

# %%
# DCC_PbSN_04
## PRETEST 20210119 Shots 28-32
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  L
# start shot
#  28
# stop shot
#  32
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  177.355593 +/- 0.17477710 (0.10%) (init = 125)
#     n:   37.9246729 +/- 1.40220978 (3.70%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.872
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  178.312939 +/- 0.18461524 (0.10%) (init = 125)
#     n:   37.4191805 +/- 1.43706619 (3.84%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.873
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  178.506678 +/- 0.16624789 (0.09%) (init = 125)
#     n:   39.7009370 +/- 1.51360879 (3.81%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.861
# ...

# %%
# DCC_PbSN_04
## postest 20210201 Shots 18-22
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210201
# manual(m) or list(l)
#  L
# start shot
#  18
# stop shot
#  22
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  176.594051 +/- 0.16518881 (0.09%) (init = 125)
#     n:   39.7466719 +/- 1.53956050 (3.87%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.856
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  177.780398 +/- 0.16770795 (0.09%) (init = 125)
#     n:   27.6048915 +/- 0.79506355 (2.88%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.838
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  175.525646 +/- 0.15409777 (0.09%) (init = 125)
#     n:   40.6073781 +/- 1.52917166 (3.77%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.853
# ...

# %%
# DCC_PbSN_09
## PRETEST 20210119 Shots 78-82
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  L
# start shot
#  78
# stop shot
#  82
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  178.580716 +/- 0.17720946 (0.10%) (init = 125)
#     n:   41.7814869 +/- 1.73329011 (4.15%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.869
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  179.098855 +/- 0.19479651 (0.11%) (init = 125)
#     n:   39.7217108 +/- 1.64236555 (4.13%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.880
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  177.190683 +/- 0.12983064 (0.07%) (init = 125)
#     n:   45.7177833 +/- 1.62668296 (3.56%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.849
# ...

# %%
# DCC_PbSN_09
## postest 20210201 Shots 40-45
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210201
# manual(m) or list(l)
#  L
# start shot
#  40
# stop shot
#  45
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  177.723110 +/- 0.14500995 (0.08%) (init = 125)
#     n:   35.4366111 +/- 1.10311500 (3.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.845
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  177.414774 +/- 0.17171001 (0.10%) (init = 125)
#     n:   37.6188221 +/- 1.40889493 (3.75%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.862
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  178.333657 +/- 0.14149661 (0.08%) (init = 125)
#     n:   30.2275218 +/- 0.86237610 (2.85%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.809
# ...

# %%
# DCC_PbSN_11
## postest 20210119 Shots 96-100
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  L
# start shot
#  96
# stop shot
#  100
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  174.426779 +/- 0.18129441 (0.10%) (init = 125)
#     n:   36.7367780 +/- 1.47095643 (4.00%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.854
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  173.464315 +/- 0.14862356 (0.09%) (init = 125)
#     n:   38.1460901 +/- 1.34794117 (3.53%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.845
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  175.582940 +/- 0.18199692 (0.10%) (init = 125)
#     n:   26.3490545 +/- 0.80045699 (3.04%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.837
# ...

# %%
# DCC_PbSN_11
## postest 20210119 Shots 28-32
# %run calculate_IC.py

# %%
# DCC_PbSN_11
## postest 20210201 Shots 03-07
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210201
# manual(m) or list(l)
#  L
# start shot
#  3
# stop shot
#  7
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  171.946625 +/- 0.17961554 (0.10%) (init = 125)
#     n:   38.8879132 +/- 1.53641033 (3.95%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.878
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  173.078072 +/- 0.15025266 (0.09%) (init = 125)
#     n:   27.3059975 +/- 0.75969003 (2.78%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.818
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  173.074647 +/- 0.18639666 (0.11%) (init = 125)
#     n:   26.7244879 +/- 0.81680922 (3.06%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.853
# ...

# %%
# pBsN_001
## PRETEST 20201221 Shots 51-55
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201221
# manual(m) or list(l)
#  L
# start shot
#  51
# stop shot
#  55
# Name of Data Folder PB
# Date of Data Batch 20201221
# [[Variables]]
#     Ic:  175.088543 +/- 0.17057690 (0.10%) (init = 125)
#     n:   40.8924892 +/- 1.65060967 (4.04%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.865
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20201221
# [[Variables]]
#     Ic:  175.579786 +/- 0.13550513 (0.08%) (init = 125)
#     n:   33.6478767 +/- 1.02033636 (3.03%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.816
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20201221
# [[Variables]]
#     Ic:  176.333687 +/- 0.15878305 (0.09%) (init = 125)
#     n:   29.8771489 +/- 0.92132928 (3.08%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.826
# ...

# %%
# pBsN_001
## postest 20210201 Shots 26-30
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210201
# manual(m) or list(l)
#  L
# start shot
#  26
# stop shot
#  30
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  171.587331 +/- 0.21121985 (0.12%) (init = 125)
#     n:   35.8123089 +/- 1.52242291 (4.25%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.878
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  172.975709 +/- 0.19007665 (0.11%) (init = 125)
#     n:   28.1629700 +/- 0.91897294 (3.26%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.855
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  171.349740 +/- 0.20147395 (0.12%) (init = 125)
#     n:   35.2547749 +/- 1.41827296 (4.02%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.876
# ...

# %%
# pBsN_004
## pRETEST 20201223 Shots 22-26
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201223
# manual(m) or list(l)
#  L
# start shot
#  22
# stop shot
#  26
# Name of Data Folder PB
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  173.283452 +/- 0.13351947 (0.08%) (init = 125)
#     n:   36.1932454 +/- 1.18112142 (3.26%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.819
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  173.886745 +/- 0.16675745 (0.10%) (init = 125)
#     n:   31.1646341 +/- 1.01918792 (3.27%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.843
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20201223
# [[Variables]]
#     Ic:  174.409762 +/- 0.19884570 (0.11%) (init = 125)
#     n:   39.3838905 +/- 1.70692987 (4.33%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.878
# ...

# %%
# pBsN_004
## POSTEST 20210201 Shots 33-36
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210201
# manual(m) or list(l)
#  L
# start shot
#  33
# stop shot
#  36
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  174.429976 +/- 0.18824524 (0.11%) (init = 125)
#     n:   37.8455486 +/- 1.53644902 (4.06%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.870
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  175.189226 +/- 0.18013724 (0.10%) (init = 125)
#     n:   38.6419268 +/- 1.57037805 (4.06%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.864
# ##################plotting!!!############
# Name of Data Folder PB
# Date of Data Batch 20210201
# [[Variables]]
#     Ic:  175.943158 +/- 0.14375381 (0.08%) (init = 125)
#     n:   28.0019392 +/- 0.76704254 (2.74%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.808
# ...
