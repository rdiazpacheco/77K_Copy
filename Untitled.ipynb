# %%
## CSMC transitoin leads
## Pre test: 751-N3_010 20210329 12-16
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210329
# manual(m) or list(l)
#  l
# start shot
#  12
# stop shot
#  16
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  133.245516 +/- 0.08623902 (0.06%) (init = 125)
#     n:   43.2102774 +/- 0.95162717 (2.20%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.921
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  132.888719 +/- 0.08386455 (0.06%) (init = 125)
#     n:   45.2642699 +/- 1.01500663 (2.24%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.921
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  132.905252 +/- 0.08588913 (0.06%) (init = 125)
#     n:   43.1334970 +/- 0.96248158 (2.23%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## CSMC transitoin leads
## Post test: 751-N3_010 20210414 2-6
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210414
# manual(m) or list(l)
#  L
# start shot
#  2
# stop shot
#  6
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  136.050683 +/- 0.03902132 (0.03%) (init = 125)
#     n:   37.1586343 +/- 0.54502471 (1.47%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.734
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  138.049966 +/- 0.05437469 (0.04%) (init = 125)
#     n:   55.2192408 +/- 1.62229805 (2.94%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.740
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  139.218265 +/- 0.08112889 (0.06%) (init = 125)
#     n:   30.3084654 +/- 0.71287063 (2.35%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %% [markdown]
# # CSMC transitoin leads
# ## Pre test: 751-N3_018 20210329 37-41
# %run calculate_IC.py

# %%
## CSMC transitoin leads
## Post test: 751-N3_018 20210414 26-30
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210414
# manual(m) or list(l)
#  L
# start shot
#  26
# stop shot
#  30
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  137.376467 +/- 0.07961806 (0.06%) (init = 125)
#     n:   32.1231476 +/- 0.75240118 (2.34%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.784
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  137.499523 +/- 0.08295525 (0.06%) (init = 125)
#     n:   31.0920440 +/- 0.74639248 (2.40%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.775
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  137.399037 +/- 0.07999987 (0.06%) (init = 125)
#     n:   31.6578786 +/- 0.73394720 (2.32%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## CSMC transitoin leads
## Pre test: 751-N3_020 20210329 4-8
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210329
# manual(m) or list(l)
#  L
# start shot
#  4
# stop shot
#  8
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  135.253049 +/- 0.04988635 (0.04%) (init = 125)
#     n:   51.1616424 +/- 0.95233137 (1.86%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.872
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  135.572261 +/- 0.05865238 (0.04%) (init = 125)
#     n:   39.6939889 +/- 0.64477273 (1.62%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.884
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  135.418239 +/- 0.04750730 (0.04%) (init = 125)
#     n:   44.7312189 +/- 0.72262302 (1.62%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## CSMC transitoin leads
## Psot test: 751-N3_020 202104014 33-37
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210414
# manual(m) or list(l)
#  L
# start shot
#  33
# stop shot
#  37
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  137.056290 +/- 0.05314156 (0.04%) (init = 125)
#     n:   41.3359877 +/- 0.93455234 (2.26%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.714
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  137.848949 +/- 0.08247681 (0.06%) (init = 125)
#     n:   32.7379144 +/- 0.78059858 (2.38%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.798
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  137.177498 +/- 0.07752704 (0.06%) (init = 125)
#     n:   35.0243688 +/- 0.83751534 (2.39%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## CSMC transitoin leads
## Pre test: 751-N3_029 44-48 
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210329
# manual(m) or list(l)
#  L
# start shot
#  44
# stop shot
#  48
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  138.587759 +/- 0.12251915 (0.09%) (init = 125)
#     n:   25.9178157 +/- 0.60519191 (2.34%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.866
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  137.081942 +/- 0.06225151 (0.05%) (init = 125)
#     n:   46.7096370 +/- 1.17333988 (2.51%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.811
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  137.003053 +/- 0.05691887 (0.04%) (init = 125)
#     n:   52.6065851 +/- 1.34113550 (2.55%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## CSMC transitoin leads
## Post test: 751-N3_029 20210414 40-44
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210414
# manual(m) or list(l)
#  L
# start shot
#  40
# stop shot
#  44
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  141.019825 +/- 0.08092156 (0.06%) (init = 125)
#     n:   35.8074784 +/- 0.87844352 (2.45%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.811
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  140.445834 +/- 0.09740683 (0.07%) (init = 125)
#     n:   48.0944937 +/- 1.61647178 (3.36%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.866
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  141.182169 +/- 0.11062722 (0.08%) (init = 125)
#     n:   33.9479194 +/- 0.91727397 (2.70%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## CSMC transitoin leads
## Pre test: 751-N3_030 20210329 23-27
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210329
# manual(m) or list(l)
#  L
# start shot
#  23
# stop shot
#  27
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  61.1941339 +/- 0.17140583 (0.28%) (init = 125)
#     n:   19.8032402 +/- 0.78784770 (3.98%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.936
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  61.7254488 +/- 0.17279314 (0.28%) (init = 125)
#     n:   19.6676292 +/- 0.76426546 (3.89%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.939
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  61.5177115 +/- 0.11280153 (0.18%) (init = 125)
#     n:   19.6928994 +/- 0.65100268 (3.31%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## CSMC transitoin leads
## Post test: 751-N3_030 20210414 10-14
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210414
# manual(m) or list(l)
#  L
# start shot
#  10
# stop shot
#  14
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  137.108047 +/- 0.04082343 (0.03%) (init = 125)
#     n:   35.5832613 +/- 0.68612212 (1.93%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.442
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  136.668465 +/- 0.04698711 (0.03%) (init = 125)
#     n:   35.4201587 +/- 0.66779949 (1.89%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.642
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  137.272895 +/- 0.06693887 (0.05%) (init = 125)
#     n:   33.8772219 +/- 0.74836159 (2.21%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## CSMC transitoin leads
## Pre test: 751-N3_033 20-20210329 30-34
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210329
# manual(m) or list(l)
#  L
# start shot
#  30
# stop shot
#  34
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  134.263440 +/- 0.13485201 (0.10%) (init = 125)
#     n:   36.8821847 +/- 0.95014831 (2.58%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.939
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  134.096005 +/- 0.13147571 (0.10%) (init = 125)
#     n:   39.1416671 +/- 1.04760356 (2.68%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.938
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210329
# [[Variables]]
#     Ic:  132.836092 +/- 0.13274903 (0.10%) (init = 125)
#     n:   49.5619271 +/- 1.58999845 (3.21%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
## CSMC transitoin leads
## Post test: 751-N3_033 20210414 18-22
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210414
# manual(m) or list(l)
#  L
# start shot
#  18
# stop shot
#  22
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  138.727047 +/- 0.11292489 (0.08%) (init = 125)
#     n:   49.5219673 +/- 1.74117935 (3.52%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.902
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  138.826815 +/- 0.13857758 (0.10%) (init = 125)
#     n:   52.4678294 +/- 2.11459402 (4.03%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.924
# ##################plotting!!!############
# Name of Data Folder CSMC
# Date of Data Batch 20210414
# [[Variables]]
#     Ic:  139.269103 +/- 0.15388082 (0.11%) (init = 125)
#     n:   48.6871015 +/- 2.04407578 (4.20%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...
