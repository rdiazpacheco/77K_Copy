# %%
##TFMC degradation analysis for Raspberry

# %%
# DCC_PbSN_10
## pretest 20210119 Shots 
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  l
# start shot
#  86
# stop shot
#  90
# Name of Data Folder Rasp
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  172.555086 +/- 0.17478434 (0.10%) (init = 125)
#     n:   38.7978808 +/- 1.48204927 (3.82%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.877
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  173.108463 +/- 0.19417938 (0.11%) (init = 125)
#     n:   37.6588283 +/- 1.52940332 (4.06%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.879
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  172.816814 +/- 0.15502482 (0.09%) (init = 125)
#     n:   39.6679342 +/- 1.48666195 (3.75%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# DCC_PbSN_10
## post test 20210222 Shots 78-82
# %run calculate_IC.py

# %%
# DCC_PbSN_12
## pretest 20210119 Shots 105-110
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210119
# manual(m) or list(l)
#  l
# start shot
#  105
# stop shot
#  110
# Name of Data Folder Rasp
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  169.374444 +/- 0.15255494 (0.09%) (init = 125)
#     n:   38.1743148 +/- 1.41726715 (3.71%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.846
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  168.850217 +/- 0.19275586 (0.11%) (init = 125)
#     n:   39.6335330 +/- 1.66649990 (4.20%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.889
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210119
# [[Variables]]
#     Ic:  169.377071 +/- 0.11758119 (0.07%) (init = 125)
#     n:   29.1621414 +/- 0.77124173 (2.64%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# DCC_PbSN_12
## post test 20210222 Shots 87-91
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210222
# manual(m) or list(l)
#  l
# start shot
#  87
# stop shot
#  91
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  154.797261 +/- 0.18652010 (0.12%) (init = 125)
#     n:   41.2476115 +/- 1.32593519 (3.21%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.948
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  155.088345 +/- 0.15818075 (0.10%) (init = 125)
#     n:   42.8185597 +/- 1.27904386 (2.99%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.941
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  154.910634 +/- 0.15040566 (0.10%) (init = 125)
#     n:   45.6434243 +/- 1.37359329 (3.01%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# DCC_PbSN_21
## pretest 20210202 Shots 46-50
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210202
# manual(m) or list(l)
#  l
# start shot
#  46
# stop shot
#  50
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  172.282002 +/- 0.35340649 (0.21%) (init = 125)
#     n:   29.8770928 +/- 1.56877587 (5.25%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.907
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  171.405324 +/- 0.21177559 (0.12%) (init = 125)
#     n:   37.0523040 +/- 1.65252004 (4.46%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.876
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  171.022105 +/- 0.26412845 (0.15%) (init = 125)
#     n:   36.1573069 +/- 1.79140566 (4.95%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# DCC_PbSN_21
## post test 20210222 Shots 72-76
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210222
# manual(m) or list(l)
#  l
# start shot
#  72
# stop shot
#  76
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  153.351579 +/- 0.19753607 (0.13%) (init = 125)
#     n:   45.4235690 +/- 1.96508212 (4.33%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.930
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  152.498882 +/- 0.24344000 (0.16%) (init = 125)
#     n:   47.1723081 +/- 2.35662239 (5.00%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.944
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  152.428886 +/- 0.23324483 (0.15%) (init = 125)
#     n:   47.2378988 +/- 2.36315967 (5.00%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# DCC_PbSN_26
## pretest 20210202 Shots 23-27
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210202
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  23 25 26 27
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  174.246625 +/- 0.17400080 (0.10%) (init = 125)
#     n:   37.7306098 +/- 1.50769436 (4.00%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.850
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  177.353444 +/- 0.44112408 (0.25%) (init = 125)
#     n:   25.9032962 +/- 1.36613866 (5.27%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.914
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  176.298438 +/- 0.18332838 (0.10%) (init = 125)
#     n:   34.7348737 +/- 1.46387173 (4.21%) (init = 20)
# ...

# %%
# DCC_PbSN_26
## post test 20210222 Shots 87-88
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210222
# manual(m) or list(l)
#  l
# start shot
#  87
# stop shot
#  88
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  154.797261 +/- 0.18652010 (0.12%) (init = 125)
#     n:   41.2476115 +/- 1.32593519 (3.21%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.948
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  155.088345 +/- 0.15818075 (0.10%) (init = 125)
#     n:   42.8185597 +/- 1.27904386 (2.99%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.941
# ##################plotting!!!############

# %%
# DCC_PbSN_32
## pretest 20210202 Shots 10-14
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210202
# manual(m) or list(l)
#  l
# start shot
#  10
# stop shot
#  14
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  173.733545 +/- 0.19253725 (0.11%) (init = 125)
#     n:   42.0343936 +/- 1.90606608 (4.53%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.874
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  175.176276 +/- 0.24632809 (0.14%) (init = 125)
#     n:   36.9046842 +/- 1.77667169 (4.81%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.888
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  174.635410 +/- 0.17304864 (0.10%) (init = 125)
#     n:   36.9908640 +/- 1.44975877 (3.92%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# DCC_PbSN_32
## pretest 20210222 Shots 104-106
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210222
# manual(m) or list(l)
#  l
# start shot
#  104
# stop shot
#  106
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  137.582961 +/- 0.18107233 (0.13%) (init = 125)
#     n:   51.3327335 +/- 2.12795939 (4.15%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.952
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  140.497715 +/- 0.33194880 (0.24%) (init = 125)
#     n:   43.9408151 +/- 2.73130961 (6.22%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.955
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  138.380836 +/- 0.18670739 (0.13%) (init = 125)
#     n:   84.1180796 +/- 6.03544005 (7.17%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# DCC_PbSN_36
## pretest 20210202 Shots 30-34
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210202
# manual(m) or list(l)
#  l
# start shot
#  30
# stop shot
#  34
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  176.591144 +/- 0.18132372 (0.10%) (init = 125)
#     n:   28.8889241 +/- 0.95502480 (3.31%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.836
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  176.872990 +/- 0.21672341 (0.12%) (init = 125)
#     n:   37.0004220 +/- 1.65151341 (4.46%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.874
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210202
# [[Variables]]
#     Ic:  176.829921 +/- 0.24785743 (0.14%) (init = 125)
#     n:   36.3229345 +/- 1.70328970 (4.69%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %%
# DCC_PbSN_36
## pretest 20210222 Shots 112-116
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20210222
# manual(m) or list(l)
#  l
# start shot
#  112
# stop shot
#  116
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  70.2356208 +/- 0.24974393 (0.36%) (init = 125)
#     n:   99.9999999 +/- 15.2231335 (15.22%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.978
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  70.4231667 +/- 0.47904346 (0.68%) (init = 125)
#     n:   99.9999999 +/- 24.2544253 (24.25%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.984
# ##################plotting!!!############
# Name of Data Folder Rasp
# Date of Data Batch 20210222
# [[Variables]]
#     Ic:  70.0288724 +/- 0.23905763 (0.34%) (init = 125)
#     n:   99.9999923 +/- 14.8276768 (14.83%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...
